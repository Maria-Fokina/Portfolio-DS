# %% [markdown]
# # Проект  для GoProtect"Стандартизация названий спортивных школ"
#
#
# ### Описание проекта
# Сервис  “Мой Чемпион” помогает спортивным школам фигурного катания, тренерам мониторить результаты своих подопечных и планировать дальнейшее развитие спортсменов.
#
# ### Цель
# Создать решение для стандартизации названий спортивных школ.
# Например одна и та же школа может быть записана по разному
# Надо сопоставить эти варианты эталонному названию из предоставленной таблицы
#
# ### План проекта:
# 1. Загрузка и изучение данных
# 2. Предобработка данных
# 3. Преобразование тренировочной выборки (аугментация)
# 4. Обучение модели
# 5. Оценка модели
# 6. Итоговый вывод

# %% [markdown]
# ## 1. Загрузка и изучение данных

# %%
pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in d:\datasc\a\lib\site-packages (3.0.1)
# Requirement already satisfied: tqdm in d:\datasc\a\lib\site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: numpy in d:\datasc\a\lib\site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in d:\datasc\a\lib\site-packages (from sentence-transformers) (4.42.2)
# Requirement already satisfied: huggingface-hub>=0.15.1 in d:\datasc\a\lib\site-packages (from sentence-transformers) (0.23.4)
# Requirement already satisfied: Pillow in d:\datasc\a\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: scikit-learn in d:\datasc\a\lib\site-packages (from sentence-transformers) (1.2.1)
# Requirement already satisfied: torch>=1.11.0 in d:\datasc\a\lib\site-packages (from sentence-transformers) (1.12.1)
# Requirement already satisfied: scipy in d:\datasc\a\lib\site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: requests in d:\datasc\a\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\datasc\a\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\datasc\a\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.4.0)
# Requirement already satisfied: filelock in d:\datasc\a\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\datasc\a\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in d:\datasc\a\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (22.0)
# Requirement already satisfied: colorama in d:\datasc\a\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in d:\datasc\a\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2022.7.9)
# Requirement already satisfied: safetensors>=0.4.1 in d:\datasc\a\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in d:\datasc\a\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\datasc\a\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in d:\datasc\a\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\datasc\a\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2023.7.22)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\datasc\a\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\datasc\a\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\datasc\a\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install git+https://github.com/RussianNLP/rutransform

# %%
import pandas as pd
import numpy as np
import nltk
import os
import re
import requests
import random

from sentence_transformers.readers import InputExample
from torch.utils.data import DataLoader
from sentence_transformers import util

from nltk.tokenize import word_tokenize
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from sentence_transformers import (
     SentenceTransformer,
     InputExample,
     util,
     losses)

from IPython.display import display

# %%
#nltk.download('punkt')

# %%
RANDOM_STATE = 201123

# %%
file_path = 'C:/Users/no name/Documents/SS/datasets'
if not os.path.exists(file_path):
    file_path = '/content/'
df_train = pd.read_csv(os.path.join(file_path, 'Школы.csv'))
df_test = pd.read_csv(os.path.join(file_path, 'Примерное написание.csv'))

# %%
def basic_info (df):
    print('Первые 5 строк:')
    display(df.head())
    print()
    print('Последние 5 строк:')
    display(df.tail())
    print()
    print('Общая информация по таблице:')
    print()
    df.info()
    print()
    print('Всего явных дубликатов:', df.duplicated().sum())
    print()
    print('Количество пропусков:')
    display(df.isna().sum())
    print()

# %%
basic_info(df_train)
# Out:
# Первые 5 строк:
#    school_id                  name                region
# 0          1              Авангард    Московская область
# 1          2              Авангард     Ямало-Ненецкий АО
# 2          3               Авиатор  Республика Татарстан
# 3          4                Аврора       Санкт-Петербург
# 4          5  Ice Dream / Айс Дрим       Санкт-Петербург
# Последние 5 строк:
#      school_id                    name                 region
# 301        305                Прогресс         Алтайский край
# 302        609          "СШ "Гвоздика"  Удмуртская республика
# 303        610  СШОР "Надежда Губернии    Саратовская область
# 304        611           КФК «Айсберг»          Пермский край
# 305       1836            ООО "Триумф"                 Москва
# Общая информация по таблице:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  306 non-null    int64
#  1   name       306 non-null    object
#  2   region     306 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 7.3+ KB
#
# Всего явных дубликатов: 0
#
# Количество пропусков:
# school_id    0
# name         0
# region       0
# dtype: int64

# %%
basic_info(df_test)
# Out:
# Первые 5 строк:
#    school_id                                               name
# 0       1836                                       ООО "Триумф"
# 1       1836                                Москва, СК "Триумф"
# 2        610                             СШОР "Надежда Губернии
# 3        610  Саратовская область, ГБУСО "СШОР "Надежда Губе...
# 4        609                                     "СШ "Гвоздика"
# Последние 5 строк:
#      school_id                                               name
# 890          3             Республика Татарстан, СШОР ФСО Авиатор
# 891          3             СШОР ФСО Авиатор, Республика Татарстан
# 892          3  Республика Татарстан, МБУ ДО СШОР «ФСО "Авиатор"»
# 893          2                                ЯНАО, СШ "Авангард"
# 894          1                  Московская область, СШ "Авангард"
# Общая информация по таблице:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  895 non-null    int64
#  1   name       895 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 14.1+ KB
#
# Всего явных дубликатов: 0
#
# Количество пропусков:
# school_id    0
# name         0
# dtype: int64

# %% [markdown]
# Вывод:
# 1. Данные представляют собой две таблицы, в одной эталонные наименования спортивных школ, в другой вариации написания в том числе с ошибками.
# 2. В эталонной таблице всего 306 строк и 3 колонки - id школы, регион, наименование
# 3. Во второй таблице всего 895 строк и 2 колонки - id школы,  наименование (в части случаев указано с регионом)
# 4. Эталонную таблицу, используем как тренировачную выборку, другую как тестовую.
# 5. Пропуски и явные дубликаты в дататсетах не обнаружены.

# %% [markdown]
# ## 2. Предобработка данных.

# %% [markdown]
# Алгоритм будет выявлять соответствие по основным маркерам - само название без аббревиатур и сокращений  + регион, поэтому сначала объединим наименование и регион в одну строку:

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_train.sort_values(by=['region']))
# Out:
#      school_id                                               name  \
# 301        305                                           Прогресс
# 21          22                                          Беломорец
# 65          66                                             Каскад
# 158        159                                          Созвездие
# 50          51                                        ДЮСШ по ЗВС
# 177        178                                           СШ по ФК
# 35          36                                             ГАУ СК
# 25          26                                             Брянск
# 240        241                                             ФФККВО
# 107        108                                     Мотодром Арена
# 45          46                                             Динамо
# 43          44                                      Дворец Спорта
# 58          59                                           ДЮСШ № 8
# 175        176                                          СШ по ЗВС
# 180        181                                             СШ № 1
# 30          31                                             Витязь
# 84          85                                     Ледовый дворец
# 153        154                                             Сияние
# 244        245                                  Хрустальный конек
# 76          77                                             Космос
# 266        268                           МКУ ДО «ДЮСШ «ВОСТОЧНАЯ»
# 145        146                                               Рысь
# 293        297                               ЧУДО ДЮСОШ "СИЯНИЕ"
# 208        209                                           СШОР № 2
# 46          47                                             Динамо
# 126        127                                           ООФФК ИО
# 57          58                                          ДЮСШ № 7
# 59          60                                              Ермак
# 230        231             Федерация фигурного катания на коньках
# 148        149                                        Светлогорец
# 70          71                                       КО СШ по ЗВС
# 117        118                                              Олимп
# 77          78                                             Космос
# 99         100                                           МБФСУ СШ
# 96          97                                       МАФСУ СШ № 6
# 97          98                                        МАФСУ СШ №1
# 49          50                                              Дымка
# 38          39                                           Голубева
# 39          40                                           Голубева
# 198        199                                        СШОР по ФКК
# 157        158                                           Снеговик
# 12          13                                          Аллигатор
# 178        179                                        СШ по ФККиХ
# 143        144                                        РЦСП по ФФК
# 138        139                                            Рассвет
# 79          80                                         Красноярск
# 173        174                                             СШ ЗВС
# 245        246                                       Центр по ЛВС
# 54          55                                           ДЮСШ № 2
# 206        207                                          СШОР № 1
# 209        210                                           СШОР № 2
# 17          18                                              Арена
# 34          35                                              ВСШОР
# 183        184                                            СШ № 11
# 112        113                                     Новочебоксарск
# 74          75                                   Конек Чайковской
# 135        136                                          ПроСинхро
# 105        106                                            Москвич
# 81          82                                            Легенда
# 103        104                                        МОСГОРСПОРТ
# 101        102                                              Мечта
# 137        138                                            Прусова
# 100        101                                         Медведково
# 118        119                                              Олимп
# 305       1836                                       ООО "Триумф"
# 159        160                                          Созвездие
# 299        303                                     ООО "СетПоинт"
# 290        294                   ГБУ "МосСпортОбъект" ЛЦ "Звезда"
# 289        293                         АНО Лига фигурного катания
# 260        262                                          Южный Лед
# 9           10            Академия синхронного катания на коньках
# 251        252                                 ЦСКА им. С.А. Жука
# 250        251                                               ЦСКА
# 14          15                                    Ангелы Плющенко
# 246        247                              Центр развития спорта
# 243        244                                        Хрустальный
# 19          20                            Армия фигурного катания
# 210        211                                           СШОР № 2
# 27          28                                        Вдохновение
# 33          34                                            Волкова
# 95          96                                              МАФКК
# 170        171                                            Столица
# 160        161                                         Сокольники
# 147        148                                              Салют
# 226        227                                            УОР № 1
# 247        248                        Центр спортивных технологий
# 115        116                                           Одинцово
# 128        129                                          Пахомовой
# 297        301                              МБУ "ЦФКиС г. Лобня"
# 109        110                                       Наши надежды
# 91          92                                            Ляпкина
# 0            1                                           Авангард
# 41          42                                            Давыдов
# 90          91                                          Лыткарино
# 69          70                                    Клин спортивный
# 20          21                            Армия фигурного катания
# 15          16                                    Ангелы Плющенко
# 13          14                                  Альберта Демченко
# 186        187                                            СШ № 6
# 185        186                                             СШ № 6
# 68          69                                           Кировска
# 261        263                                             Юность
# 256        258                                              Челны
# 36          37                             ГБОУ ДО НО СШОР по ЛВС
# 193        194                                        СШОР по ЛВС
# 44          45                               Дворец спорта Юность
# 232        233                                        ФОК городец
# 119        120                                              Олимп
# 149        150                                    Северная Звезда
# 102        103                                          Мещерский
# 182        183                                            СШ № 1
# 165        166                                    Спорт-индустрия
# 22          23                                             Бердск
# 248        249                                               ЦЗВС
# 211        212                                          СШОР № 35
# 120        121                                              Олимп
# 202        203                                           СШОР № 1
# 83          84                                  Ледовое поколение
# 300        304                                          СШ по ЗВС
# 181        182                                             СШ № 1
# 203        204                                           СШОР № 1
# 304        611                                      КФК «Айсберг»
# 127        128                                            Орленок
# 224        225                                             Триумф
# 114        115                                                 О2
# 167        168                                              Старт
# 132        133                                              Полюс
# 31          32                                            Владлед
# 121        122                                              Олимп
# 146        147                                      Салаватинвест
# 204        205                                           СШОР № 1
# 288        292                                            АНО ШФК
# 298        302                                              СШ №2
# 234        235                                             ФФК РБ
# 55          56                                           ДЮСШ № 2
# 236        237                                               ФФКК
# 66          67                                           Керриган
# 189        190                                             СШ №6
# 238        239                                            ФФКК РК
# 150        151                                   Северная Олимпия
# 217        218                                            СШОР №1
# 108        109                                           МУ СШ №1
# 295        299                                     РФСОО "ФФККРК"
# 67          68                                           Керриган
# 5            6                                            Айсберг
# 161        162                               Союз мастеров спорта
# 188        189                                              СШ №4
# 176        177                                          СШ по ЛВС
# 201        202                                        СШОР по ФФК
# 196        197                СШОР по фигурному катанию на конька
# 199        200                                        СШОР по ФКК
# 218        219                                            СШОР №1
# 10          11                                       Академия ФКК
# 139        140                                       РОО СФФК РСЯ
# 141        142                                        РССШ по ЗВС
# 171        172                                             Стрела
# 152        153                                                СиТ
# 42          43                                           Движение
# 229        230                                     ФАУ МО РФ ЦСКА
# 2            3                                            Авиатор
# 142        143                                              РСШОР
# 87          88                                            Ледокол
# 200        201                                     СШОР по ФККиШТ
# 129        130                                           ПГУФКСиТ
# 212        213                                           СШОР № 4
# 82          83                                   Ледовая академия
# 154        155                                          СК РОФФКК
# 136        137                                       Профессионал
# 140        141                                             РОФФКК
# 215        216                                           СШОР № 6
# 123        124                                        Олимпийский
# 6            7                                            Айсберг
# 296        300                            ГАУ РО "ХК "Рязань-ВДВ"
# 216        217                                           СШОР № 6
# 205        206                                          СШОР No 1
# 32          33                                            Волгарь
# 53          54                                          ДЮСШ № 10
# 106        107    Московская академия фигурного катания на конька
# 92          93                                              Маска
# 255        257                         ЦФКСиЗ Фрунзенского района
# 254        256                          ЦФКСиЗ Московского района
# 253        254                    ЦФКСиЗ Василеостровского района
# 252        253                   ЦФКСиЗ Красногвардейского района
# 78          79                                     Красная звезда
# 249        250                ЦОП по фигурному катанию на коньках
# 104        105                                 СК ФК Т. Москвиной
# 110        111                                        Невский лед
# 4            5                               Ice Dream / Айс Дрим
# 23          24                               Школа ФК Е. Бережной
# 282        285  Отделение фигурного катания «Ника» ООО «Клуб СБС»
# 228        229                                            Фаворит
# 24          25                                  Бриллиантовый лед
# 222        223                                              ТИТУЛ
# 221        222                                              Темпо
# 16          17                           ТОП ТИМ - лучшая команда
# 219        220                                            СШОР №1
# 257        259                                            Чемпион
# 286        289                                       ООО "Пируэт"
# 281        284                                        ООО "ГЛАЙД"
# 280        283                                        Proice Kids
# 279        282  СШ (ОРК) филиала ФАУ МО РФ ЦСКА (СКА, г. Санкт...
# 278        281                СФК «Серпантин» (И П Шалимова Т.А.)
# 277        280                                       Энергия льда
# 276        279                                      Созвездие Айс
# 275        278                                   СФК Империя Льда
# 274        277                    НП КФК "Динамо-Санкт-Петербург"
# 273        276                                   Северная Столица
# 272        275                              ООО "ЛЕДОВАЯ ИСТОРИЯ"
# 271        274             "Голден Айс Петергоф" (ГБУ СШ "Манеж")
# 270        273                                             Каскад
# 269        272                                   СК ФК «Open Ice»
# 268        271                                         ИП Иванова
# 267        270                             ЦФКСиЗ Невского района
# 284        287    СФК "УЗОР" ИП Баранчикова Наталия Александровна
# 285        288                                           СТАРТАЙС
# 287        291                                            Динамит
# 130        131                                             Пируэт
# 124        125                                            ОЛИМПИЯ
# 133        134                                             Прибой
# 93          94                                             Мастер
# 61          62                                       Звездный лед
# 88          89                                          Локомотив
# 60          61                                             Звезда
# 56          57                                           ДЮСШ № 4
# 151        152                                    Северное Сияние
# 155        156                               Хоккейный клуб "СКА"
# 197        198               СШОР по фигурному катанию на коньках
# 51          52                                  ДЮСШ СК Юбилейный
# 191        192                            СШОР Колпинского района
# 48          49                                           Династия
# 163        164                                            Спартак
# 169        170                                           Стартайс
# 37          38                                         Голден айс
# 47          48                             Динамо Санкт-Петербург
# 62          63                                      Золотой конек
# 207        208                        СШОР № 1 Московского района
# 283        286                               СК ФК «Ice Prestige»
# 3            4                                             Аврора
# 29          30                                         Вилеса Айс
# 63          64                                    Золотые надежды
# 28          29                                            Вершина
# 26          27                                        Буревестник
# 11          12                                       Академия ФКК
# 303        610                             СШОР "Надежда Губернии
# 242        243                                       Холмск-Арена
# 80          81                                           Кристалл
# 168        169                                              Старт
# 184        185                                            СШ № 19
# 89          90                                          Локомотив
# 125        126                                            ОЛИМПИЯ
# 7            8                                            Айсберг
# 262        264                                             Юность
# 258        260                                            Энергия
# 292        296                        МБОУ ДО СШ №8 "Локомотив",
# 71          72                МАУ ДО «СШ им. Александра Козицына»
# 111        112                                               НЛФК
# 294        298                                 АНО СК "ЮНАРМЕЙЦЫ"
# 8            9                                          Звездочка
# 179        180                              СШ по хоккею с шайбой
# 166        167                                   Ставрополь Арена
# 174        175                                             СШ ЗВС
# 241        242                                             ФФККСК
# 162        163                               Союз мастеров спорта
# 98          99                                      МБУ СШ по ЗВС
# 235        236                                             ФФК СК
# 190        191                                 СШ, г.Невинномысск
# 220        221                                            СШОР №3
# 194        195                                        СШОР по ЛВС
# 231        232                                                ФКК
# 195        196                       СШОР по ледовым видам спорта
# 73          74                                    Конаковский лед
# 233        234                                                ФФК
# 192        193                                        СШОР по ЗВС
# 40          41                                             Гусева
# 156        157                                              Смена
# 85          86                                     Ледовый дворец
# 116        117                                             ОКСШОР
# 291        295                                       ГУ ТО ОКСШОР
# 134        135                                             Прибой
# 52          53                                          ДЮСШ No 1
# 64          65                                            Ижсталь
# 227        228                                               УФФК
# 302        609                                     "СШ "Гвоздика"
# 86          87                              Ледовый дворец спорта
# 172        173                                                 СШ
# 263        265                                             Юность
# 237        238                                               ФФКК
# 122        123                                           Олимпиец
# 131        132                                             Пируэт
# 223        224                                              Тодес
# 259        261                                       Южное сияние
# 187        188                                             СШ № 7
# 144        145                                            РЦСПЗВС
# 94          95                                        МАУ СШ No 7
# 72          73                                  Команда Дмитриева
# 225        226                                        Ужный урал
# 213        214                                           СШОР № 4
# 264        266                                             Юность
# 164        165                                            Спартак
# 265        267                                               Ямал
# 239        240                                          ФФКК ЯНАО
# 18          19                                             Арктур
# 1            2                                           Авангард
# 75          76                                            Контакт
# 113        114                                      Новый уренгой
# 214        215                                           СШОР № 4
#
#                       region
# 301           Алтайский край
# 21     Архангельская область
# 65     Архангельская область
# 158     Астраханская область
# 50      Белгородская область
# 177         Брянская область
# 35          Брянская область
# 25          Брянская область
# 240     Владимирская область
# 107     Владимирская область
# 45      Владимирская область
# 43      Владимирская область
# 58      Владимирская область
# 175    Волгоградская область
# 180      Вологодская область
# 30       Вологодская область
# 84       Вологодская область
# 153      Воронежская область
# 244      Воронежская область
# 76       Воронежская область
# 266      Воронежская область
# 145      Воронежская область
# 293      Воронежская область
# 208       Забайкальский край
# 46        Ивановская область
# 126        Иркутская область
# 57         Иркутская область
# 59         Иркутская область
# 230  Калининградская область
# 148  Калининградская область
# 70   Калининградская область
# 117        Калужская область
# 77         Калужская область
# 99       Кемеровская область
# 96       Кемеровская область
# 97       Кемеровская область
# 49         Кировская область
# 38        Костромская бласть
# 39       Костромская область
# 198       Краснодарский край
# 157       Краснодарский край
# 12        Краснодарский край
# 178       Краснодарский край
# 143       Краснодарский край
# 138        Красноярский край
# 79         Красноярский край
# 173        Красноярский край
# 245        Красноярский край
# 54        Курганская область
# 206       Курганская область
# 209       Курганская область
# 17           Курская область
# 34     Ленинградская область
# 183         Липецкая область
# 112                   Москва
# 74                    Москва
# 135                   Москва
# 105                   Москва
# 81                    Москва
# 103                   Москва
# 101                   Москва
# 137                   Москва
# 100                   Москва
# 118                   Москва
# 305                   Москва
# 159                   Москва
# 299                   Москва
# 290                   Москва
# 289                   Москва
# 260                   Москва
# 9                     Москва
# 251                   Москва
# 250                   Москва
# 14                    Москва
# 246                   Москва
# 243                   Москва
# 19                    Москва
# 210                   Москва
# 27                    Москва
# 33                    Москва
# 95                    Москва
# 170                   Москва
# 160                   Москва
# 147       Московская область
# 226       Московская область
# 247       Московская область
# 115       Московская область
# 128       Московская область
# 297       Московская область
# 109       Московская область
# 91        Московская область
# 0         Московская область
# 41        Московская область
# 90        Московская область
# 69        Московская область
# 20        Московская область
# 15        Московская область
# 13        Московская область
# 186       Мурманская область
# 185       Мурманская область
# 68        Мурманская область
# 261       Мурманская область
# 256         Набережные челны
# 36     Нижегородская область
# 193    Нижегородская область
# 44     Нижегородская область
# 232    Нижегородская область
# 119    Нижегородская область
# 149    Нижегородская область
# 102    Нижегородская область
# 182    Нижегородская область
# 165     Новгородская область
# 22     Новосибирская область
# 248    Новосибирская область
# 211           Омская область
# 120     Оренбургская область
# 202     Оренбургская область
# 83         Орловская область
# 300       Пензенская область
# 181       Пензенская область
# 203            Пермский край
# 304            Пермский край
# 127            Пермский край
# 224            Пермский край
# 114            Пермский край
# 167            Пермский край
# 132          Приморский край
# 31           Приморский край
# 121        Псковская область
# 146  Республика Башкортостан
# 204  Республика Башкортостан
# 288  Республика Башкортостан
# 298  Республика Башкортостан
# 234  Республика Башкортостан
# 55        Республика Карелия
# 236       Республика Карелия
# 66        Республика Карелия
# 189       Республика Карелия
# 238          Республика Коми
# 150          Республика Коми
# 217          Республика Коми
# 108          Республика Коми
# 295          Республика Коми
# 67        Республика Корелия
# 5            Республика Крым
# 161          Республика Крым
# 188          Республика Крым
# 176      Республика Марий Эл
# 201      Республика Мордовия
# 196      Республика Мордовия
# 199      Республика Мордовия
# 218      Республика Мордовия
# 10       Республика Мордовия
# 139          Республика Саха
# 141          Республика Саха
# 171     Республика Татарстан
# 152     Республика Татарстан
# 42      Республика Татарстан
# 229     Республика Татарстан
# 2       Республика Татарстан
# 142     Республика Татарстан
# 87      Республика Татарстан
# 200     Республика Татарстан
# 129     Республика Татарстан
# 212       Республика Чувашия
# 82        Ростовская область
# 154       Ростовская область
# 136       Ростовская область
# 140       Ростовская область
# 215       Ростовская область
# 123        Рязанская область
# 6          Рязанская область
# 296        Рязанская область
# 216        Рязанская область
# 205        Самарская область
# 32         Самарская область
# 53         Самарская область
# 106        Самарская область
# 92           Санкт-Петербург
# 255          Санкт-Петербург
# 254          Санкт-Петербург
# 253          Санкт-Петербург
# 252          Санкт-Петербург
# 78           Санкт-Петербург
# 249          Санкт-Петербург
# 104          Санкт-Петербург
# 110          Санкт-Петербург
# 4            Санкт-Петербург
# 23           Санкт-Петербург
# 282          Санкт-Петербург
# 228          Санкт-Петербург
# 24           Санкт-Петербург
# 222          Санкт-Петербург
# 221          Санкт-Петербург
# 16           Санкт-Петербург
# 219          Санкт-Петербург
# 257          Санкт-Петербург
# 286          Санкт-Петербург
# 281          Санкт-Петербург
# 280          Санкт-Петербург
# 279          Санкт-Петербург
# 278          Санкт-Петербург
# 277          Санкт-Петербург
# 276          Санкт-Петербург
# 275          Санкт-Петербург
# 274          Санкт-Петербург
# 273          Санкт-Петербург
# 272          Санкт-Петербург
# 271          Санкт-Петербург
# 270          Санкт-Петербург
# 269          Санкт-Петербург
# 268          Санкт-Петербург
# 267          Санкт-Петербург
# 284          Санкт-Петербург
# 285          Санкт-Петербург
# 287          Санкт-Петербург
# 130          Санкт-Петербург
# 124          Санкт-Петербург
# 133          Санкт-Петербург
# 93           Санкт-Петербург
# 61           Санкт-Петербург
# 88           Санкт-Петербург
# 60           Санкт-Петербург
# 56           Санкт-Петербург
# 151          Санкт-Петербург
# 155          Санкт-Петербург
# 197          Санкт-Петербург
# 51           Санкт-Петербург
# 191          Санкт-Петербург
# 48           Санкт-Петербург
# 163          Санкт-Петербург
# 169          Санкт-Петербург
# 37           Санкт-Петербург
# 47           Санкт-Петербург
# 62           Санкт-Петербург
# 207          Санкт-Петербург
# 283          Санкт-Петербург
# 3            Санкт-Петербург
# 29           Санкт-Петербург
# 63           Санкт-Петербург
# 28           Санкт-Петербург
# 26           Санкт-Петербург
# 11                   Саранск
# 303      Саратовская область
# 242      Сахалинская область
# 80       Сахалинская область
# 168     Свердловская область
# 184     Свердловская область
# 89      Свердловская область
# 125     Свердловская область
# 7       Свердловская область
# 262     Свердловская область
# 258     Свердловская область
# 292     Свердловская область
# 71      Свердловская область
# 111     Свердловская область
# 294              Севастополь
# 8              Северодвинск
# 179       Смоленская область
# 166      Ставропольский край
# 174      Ставропольский край
# 241      Ставропольский край
# 162      Ставропольский край
# 98       Ставропольский край
# 235      Ставропольский край
# 190      Ставропольский край
# 220       Тамбовская область
# 194         Тверская область
# 231         Тверская область
# 195         Тверская область
# 73          Тверская область
# 233         Тверская область
# 192         Тверская область
# 40          Тверская область
# 156          Томская область
# 85          Тульская область
# 116         Тульская область
# 291         Тульская область
# 134        Тюменская область
# 52         Тюменская область
# 64     Удмуртская Республика
# 227    Удмуртская Республика
# 302    Удмуртская республика
# 86                 ХМАО-Югра
# 172                ХМАО-Югра
# 263                ХМАО-Югра
# 237                ХМАО-Югра
# 122                ХМАО-Югра
# 131         Хабаровский край
# 223      Челябинская область
# 259      Челябинская область
# 187      Челябинская область
# 144      Челябинская область
# 94       Челябинская область
# 72       Челябинская область
# 225      Челябинская область
# 213     Чувашская Республика
# 264     Чувашская Республика
# 164     Чувашская республика
# 265        Ямало-Ненецкий АО
# 239        Ямало-Ненецкий АО
# 18         Ямало-Ненецкий АО
# 1          Ямало-Ненецкий АО
# 75         Ямало-Ненецкий АО
# 113        Ямало-Ненецкий АО
# 214      Ярославская область

# %%
# удалим No для обозначения номера
df_train['name'] = df_train['name'].str.replace('No', '')
df_test['name'] = df_test['name'].str.replace('No', '')

# %%
df_train['name'] = df_train['name'] + ' ' + df_train ['region']
df_train = df_train.drop(['region'], axis=1)
display(df_train.head())
# Out:
#    school_id                                  name
# 0          1           Авангард Московская область
# 1          2            Авангард Ямало-Ненецкий АО
# 2          3          Авиатор Республика Татарстан
# 3          4                Аврора Санкт-Петербург
# 4          5  Ice Dream / Айс Дрим Санкт-Петербург

# %%
def clear(text):
    text = str(text).lower()
    text = re.sub(r'[^А-Яа-яёЁA-Za-zs]', ' ', text)
    text = ' '.join(text.split())
    return text

df_train['name'] = df_train['name'].apply(clear)
df_test['name'] = df_test['name'].apply(clear)

# %%
display(df_train.head())
display(df_test.head())
# Out:
#    school_id                                name
# 0          1         авангард московская область
# 1          2          авангард ямало ненецкий ао
# 2          3        авиатор республика татарстан
# 3          4              аврора санкт петербург
# 4          5  ice dream айс дрим санкт петербург
#    school_id                                             name
# 0       1836                                       ооо триумф
# 1       1836                                 москва ск триумф
# 2        610                            сшор надежда губернии
# 3        610  саратовская область гбусо сшор надежда губернии
# 4        609                                      сш гвоздика

# %%
# словарь с аббревиатурами и расшифровками
abbreviations_dict = {
        'дюсш':'детско юношеская спортивная школа',
        'сдюсшор':'специализированная детско юношеская спортивная школа олимпийского резерва',
        'сш':'спортивная школа',
        'сшор':'спортивная школа олимпийского резерва',
        'ффккр':'федерация фигурного катания на коньках россии',
        'ффк':'федерация фигурного катания',
        'фкк':'фигурного катания на коньках',
        'гау':'государственное автономное учреждение',
        'му':'муниципальное учреждение',
        'мо':'московская область',
        'ао':'автономный округ',
        'ооо':'общество с ограниченной ответственностью',
        'гбусо':'государственное бюджетное учреждение социального обслуживания',
        'уффк':'удмуртская федерация фигурного катания',
        'ффкк':'федерация фигурного катания на коньках',
        'огбу':'областное государственное бюджетное учреждение',
        'рцспзвс':'региональный центр спортивной подготовки по зимним видам спорта',
        'мау':'муниципальное автономное учреждение',
        'маудо':'муниципальное автономное учреждение дополнительного образования.',
        'то':'тульской области',
        'до':' дополнительного образования',
        'оксшор':'областная комплесная спортивная школа олимпийского резерва',
        'гу':'государственное учреждение',
        'звс':'зимним видам спорта',
        'лвс':'летним видам спорта',
        'мбу':'муниципальное бюджетное учреждение',
        'ффккск':'федерация фигурного катания на коньках ставропольского края',
        'мафкк':'московская академия фигурного катания на коньках',
        'нлфк':'национальная лига фигурного катания',
        'ано':'автономная некоммерческая организация ',
        'мбоу':'муниципальное бюджетное общеобразовательное учреждение',
        'ск':'спортивный клуб',
        'сфк':'секция фигурного катания',
        'фк':'фигурного катания',
        'цфксиз':'центр физической культуры, спорта и здоровья',
        'роффкк':'ростовская областная федерация фигурного катания на конках',
        'рсшор':'республиканская спортивная школа олимпийского резерва ',
        'русп':'региональный центр спортивной подготовки',
        'мафсу':'муниципальное автономное физкультурно-спортивное учреждение',
        'мбфсу':'муниципальное бюджетное физкультурно спортивное учреждение',
        'ооффк ио':'общественная организация федерация фигурного катания на коньках в Иркутской области',
        'мку':'муниципальное казенное учреждение',
        'шфк':'школа фигурного катания',
        'цска':'центральный спортивный клуб армии',
        'фау мо рф цска':'федеральное автономное учреждение министерства обороны российской федерации ',
        'рф':'российской федерации',
        'рссш':'республиканская специализированная спортивная школа',
        'роо':'региональная общественная организация',
        'сффк рся':'спортивная федерация фигурного катания на коньках республики саха',
        'кфк':'клуб фигурного катания ',
        'цзвс':'центр зимних видов спорта',
        'гбоу':'государственное бюджетное общеобразовательное учреждение',
        'гбу':'государственное бюджетное учреждение',
        'всшор':'всеволожская спортивная школа олимпийского резерва',
        'цфкис':'центр физической культуры и спорта',
        'уор':'училище олимпийского резерва',
        'рфсоо':'российское физкультурно спортивное общество организация',
        'фок':'физкультурно оздоровительный комплекс',    
        
    }
    
# Функция для замены аббревиатур в тексте на расшифровку
def replace_abbreviations(text):
    words = text.split()
    replaced_words = [abbreviations_dict[word] if word in abbreviations_dict else word for word in words]
    replaced_text = ' '.join(replaced_words)
    return replaced_text

# Замены аббревиатур в колонке 'name' датафрейма df_train
df_train['name'] = df_train['name'].apply(replace_abbreviations)
df_test['name'] = df_test['name'].apply(replace_abbreviations)

display(df_train)
# Out:
#      school_id                                               name
# 0            1                        авангард московская область
# 1            2           авангард ямало ненецкий автономный округ
# 2            3                       авиатор республика татарстан
# 3            4                             аврора санкт петербург
# 4            5                 ice dream айс дрим санкт петербург
# ..         ...                                                ...
# 301        305                            прогресс алтайский край
# 302        609    спортивная школа гвоздика удмуртская республика
# 303        610  спортивная школа олимпийского резерва надежда ...
# 304        611      клуб фигурного катания  айсберг пермский край
# 305       1836  общество с ограниченной ответственностью триум...
#
# [306 rows x 2 columns]

# %%
duplicates = df_train[df_train.duplicated(subset=['name'], keep=False)]
display(duplicates)
# Out:
#      school_id                                               name
# 96          97  муниципальное автономное физкультурно-спортивн...
# 97          98  муниципальное автономное физкультурно-спортивн...
# 169        170                           стартайс санкт петербург
# 185        186                спортивная школа мурманская область
# 186        187                спортивная школа мурманская область
# 206        207  спортивная школа олимпийского резерва курганск...
# 209        210  спортивная школа олимпийского резерва курганск...
# 285        288                           стартайс санкт петербург

# %% [markdown]
# Удаляем дубликаты:

# %%
df_train = df_train.drop (index=[ 97 , 186 , 209, 285, 67, 38, 25])
df_train.reset_index(drop= True , inplace= True )

# %%
df_test = df_test.drop (index=[ 97 , 186 , 209, 285, 67, 38, 25])
df_test.reset_index(drop= True , inplace= True )

# %%
with pd.option_context('display.max_rows', None):  
    display(df_train.sort_values(by=['name']))
# Out:
#      school_id                                               name
# 4            5                 ice dream айс дрим санкт петербург
# 274        283                        proice kids санкт петербург
# 0            1                        авангард московская область
# 1            2           авангард ямало ненецкий автономный округ
# 2            3                       авиатор республика татарстан
# 3            4                             аврора санкт петербург
# 282        293  автономная некоммерческая организация  лига фи...
# 287        298  автономная некоммерческая организация  спортив...
# 281        292  автономная некоммерческая организация  школа ф...
# 5            6                            айсберг республика крым
# 6            7                          айсберг рязанская область
# 7            8                       айсберг свердловская область
# 9           10     академия синхронного катания на коньках москва
# 10          11  академия фигурного катания на коньках республи...
# 11          12      академия фигурного катания на коньках саранск
# 12          13                       аллигатор краснодарский край
# 13          14               альберта демченко московская область
# 14          15                             ангелы плющенко москва
# 15          16                 ангелы плющенко московская область
# 17          18                              арена курская область
# 18          19             арктур ямало ненецкий автономный округ
# 19          20                     армия фигурного катания москва
# 20          21         армия фигурного катания московская область
# 21          22                    беломорец архангельская область
# 22          23                       бердск новосибирская область
# 24          25                  бриллиантовый лед санкт петербург
# 25          27                        буревестник санкт петербург
# 26          28                                 вдохновение москва
# 27          29                            вершина санкт петербург
# 28          30                         вилеса айс санкт петербург
# 29          31                         витязь вологодская область
# 30          32                            владлед приморский край
# 31          33                          волгарь самарская область
# 32          34                                     волкова москва
# 33          35  всеволожская спортивная школа олимпийского рез...
# 265        274  голден айс петергоф государственное бюджетное ...
# 36          38                         голден айс санкт петербург
# 37          40                       голубева костромская область
# 289        300  государственное автономное учреждение ро хк ря...
# 34          36  государственное автономное учреждение спортивн...
# 35          37  государственное бюджетное общеобразовательное ...
# 283        294  государственное бюджетное учреждение мосспорто...
# 284        295  государственное учреждение тульской области об...
# 38          41                            гусева тверская область
# 39          42                         давыдов московская область
# 40          43                      движение республика татарстан
# 41          44                 дворец спорта владимирская область
# 42          45         дворец спорта юность нижегородская область
# 56          59  детско юношеская спортивная школа владимирская...
# 55          58  детско юношеская спортивная школа иркутская об...
# 52          55  детско юношеская спортивная школа курганская о...
# 48          51  детско юношеская спортивная школа по зимним ви...
# 53          56  детско юношеская спортивная школа республика к...
# 51          54  детско юношеская спортивная школа самарская об...
# 54          57  детско юношеская спортивная школа санкт петербург
# 49          52  детско юношеская спортивная школа спортивный к...
# 50          53  детско юношеская спортивная школа тюменская об...
# 280        291                            динамит санкт петербург
# 43          46                        динамо владимирская область
# 44          47                          динамо ивановская область
# 45          48             динамо санкт петербург санкт петербург
# 46          49                           династия санкт петербург
# 47          50                            дымка кировская область
# 57          60                            ермак иркутская область
# 58          61                             звезда санкт петербург
# 59          62                       звездный лед санкт петербург
# 8            9                             звездочка северодвинск
# 60          63                      золотой конек санкт петербург
# 61          64                    золотые надежды санкт петербург
# 62          65                      ижсталь удмуртская республика
# 262        271                         ип иванова санкт петербург
# 63          66                       каскад архангельская область
# 264        273                             каскад санкт петербург
# 64          67                        керриган республика карелия
# 65          69                        кировска мурманская область
# 66          70                 клин спортивный московская область
# 297        611      клуб фигурного катания  айсберг пермский край
# 67          71  ко спортивная школа по зимним видам спорта кал...
# 69          73              команда дмитриева челябинская область
# 70          74                   конаковский лед тверская область
# 71          75                            конек чайковской москва
# 72          76            контакт ямало ненецкий автономный округ
# 73          77                         космос воронежская область
# 74          78                           космос калужская область
# 75          79                     красная звезда санкт петербург
# 76          80                       красноярск красноярский край
# 77          81                       кристалл сахалинская область
# 78          82                                     легенда москва
# 79          83                ледовая академия ростовская область
# 80          84                ледовое поколение орловская область
# 81          85                 ледовый дворец вологодская область
# 83          87                    ледовый дворец спорта хмао югра
# 82          86                    ледовый дворец тульская область
# 84          88                       ледокол республика татарстан
# 85          89                          локомотив санкт петербург
# 86          90                     локомотив свердловская область
# 87          91                       лыткарино московская область
# 88          92                         ляпкина московская область
# 89          93                              маска санкт петербург
# 90          94                             мастер санкт петербург
# 96         101                                  медведково москва
# 97         102                                       мечта москва
# 98         103                    мещерский нижегородская область
# 99         104                                 мосгорспорт москва
# 101        106                                     москвич москва
# 102        107  московская академия фигурного катания на коньк...
# 92          96  московская академия фигурного катания на коньк...
# 103        108                мотодром арена владимирская область
# 68          72  муниципальное автономное учреждение  дополните...
# 91          95  муниципальное автономное учреждение спортивная...
# 93          97  муниципальное автономное физкультурно-спортивн...
# 285        296  муниципальное бюджетное общеобразовательное уч...
# 94          99  муниципальное бюджетное учреждение спортивная ...
# 290        301  муниципальное бюджетное учреждение центр физич...
# 95         100  муниципальное бюджетное физкультурно спортивно...
# 260        268  муниципальное казенное учреждение  дополнитель...
# 104        109  муниципальное учреждение спортивная школа респ...
# 107        112  национальная лига фигурного катания свердловск...
# 105        110                    наши надежды московская область
# 106        111                        невский лед санкт петербург
# 108        113                              новочебоксарск москва
# 109        114      новый уренгой ямало ненецкий автономный округ
# 268        277  нп клуб фигурного катания  динамо санкт петерб...
# 110        115                                    о пермский край
# 112        117  областная комплесная спортивная школа олимпийс...
# 275        284  общество с ограниченной ответственностью глайд...
# 266        275  общество с ограниченной ответственностью ледов...
# 279        289  общество с ограниченной ответственностью пируэ...
# 292        303  общество с ограниченной ответственностью сетпо...
# 298       1836  общество с ограниченной ответственностью триум...
# 111        116                        одинцово московская область
# 113        118                            олимп калужская область
# 114        119                                       олимп москва
# 115        120                        олимп нижегородская область
# 116        121                         олимп оренбургская область
# 117        122                            олимп псковская область
# 118        123                                 олимпиец хмао югра
# 119        124                      олимпийский рязанская область
# 120        125                            олимпия санкт петербург
# 121        126                       олимпия свердловская область
# 122        127                         ооффк ио иркутская область
# 123        128                              орленок пермский край
# 276        285  отделение фигурного катания ника общество с ог...
# 124        129                       пахомовой московская область
# 125        130                      пгуфксит республика татарстан
# 126        131                             пируэт санкт петербург
# 127        132                            пируэт хабаровский край
# 128        133                              полюс приморский край
# 129        134                             прибой санкт петербург
# 130        135                           прибой тюменская область
# 294        305                            прогресс алтайский край
# 131        136                                   просинхро москва
# 132        137                    профессионал ростовская область
# 133        138                                     прусова москва
# 134        139                          рассвет красноярский край
# 135        140  региональная общественная организация сффк рся...
# 140        145  региональный центр спортивной подготовки по зи...
# 137        142  республиканская специализированная спортивная ...
# 138        143  республиканская спортивная школа олимпийского ...
# 288        299  российское физкультурно спортивное общество ор...
# 136        141  ростовская областная федерация фигурного катан...
# 139        144  рцсп по федерация фигурного катания краснодарс...
# 141        146                           рысь воронежская область
# 142        147              салаватинвест республика башкортостан
# 143        148                           салют московская область
# 144        149                светлогорец калининградская область
# 145        150              северная звезда нижегородская область
# 146        151                   северная олимпия республика коми
# 267        276                   северная столица санкт петербург
# 147        152                    северное сияние санкт петербург
# 269        278  секция фигурного катания империя льда санкт пе...
# 272        281  секция фигурного катания серпантин и п шалимов...
# 278        287  секция фигурного катания узор ип баранчикова н...
# 148        153                           сит республика татарстан
# 149        154                         сияние воронежская область
# 152        157                              смена томская область
# 153        158                        снеговик краснодарский край
# 270        279                      созвездие айс санкт петербург
# 154        159                     созвездие астраханская область
# 155        160                                   созвездие москва
# 156        161                                  сокольники москва
# 157        162               союз мастеров спорта республика крым
# 158        163           союз мастеров спорта ставропольский край
# 159        164                            спартак санкт петербург
# 160        165                       спартак чувашская республика
# 161        166               спорт индустрия новгородская область
# 176        181               спортивная школа вологодская область
# 185        191  спортивная школа г невинномысск ставропольский...
# 295        609    спортивная школа гвоздика удмуртская республика
# 169        174  спортивная школа зимним видам спорта красноярс...
# 170        175  спортивная школа зимним видам спорта ставропол...
# 179        184                  спортивная школа липецкая область
# 181        186                спортивная школа мурманская область
# 178        183             спортивная школа нижегородская область
# 203        209  спортивная школа олимпийского резерва забайкал...
# 186        192  спортивная школа олимпийского резерва колпинск...
# 201        207  спортивная школа олимпийского резерва курганск...
# 204        211       спортивная школа олимпийского резерва москва
# 202        208  спортивная школа олимпийского резерва московск...
# 296        610  спортивная школа олимпийского резерва надежда ...
# 205        212  спортивная школа олимпийского резерва омская о...
# 197        203  спортивная школа олимпийского резерва оренбург...
# 198        204  спортивная школа олимпийского резерва пермский...
# 187        193  спортивная школа олимпийского резерва по зимни...
# 190        196  спортивная школа олимпийского резерва по ледов...
# 188        194  спортивная школа олимпийского резерва по летни...
# 189        195  спортивная школа олимпийского резерва по летни...
# 196        202  спортивная школа олимпийского резерва по федер...
# 193        199  спортивная школа олимпийского резерва по фигур...
# 194        200  спортивная школа олимпийского резерва по фигур...
# 191        197  спортивная школа олимпийского резерва по фигур...
# 192        198  спортивная школа олимпийского резерва по фигур...
# 195        201  спортивная школа олимпийского резерва по фккиш...
# 199        205  спортивная школа олимпийского резерва республи...
# 211        218  спортивная школа олимпийского резерва республи...
# 212        219  спортивная школа олимпийского резерва республи...
# 206        213  спортивная школа олимпийского резерва республи...
# 209        216  спортивная школа олимпийского резерва ростовск...
# 210        217  спортивная школа олимпийского резерва рязанска...
# 200        206  спортивная школа олимпийского резерва самарска...
# 213        220  спортивная школа олимпийского резерва санкт пе...
# 214        221  спортивная школа олимпийского резерва тамбовск...
# 207        214  спортивная школа олимпийского резерва чувашска...
# 208        215  спортивная школа олимпийского резерва ярославс...
# 273        282  спортивная школа орк филиала фау московская об...
# 177        182                спортивная школа пензенская область
# 171        176  спортивная школа по зимним видам спорта волгог...
# 293        304  спортивная школа по зимним видам спорта пензен...
# 172        177  спортивная школа по летним видам спорта респуб...
# 173        178  спортивная школа по фигурного катания брянская...
# 174        179       спортивная школа по фкких краснодарский край
# 175        180  спортивная школа по хоккею с шайбой смоленская...
# 291        302           спортивная школа республика башкортостан
# 184        190                спортивная школа республика карелия
# 183        189                   спортивная школа республика крым
# 180        185              спортивная школа свердловская область
# 168        173                         спортивная школа хмао югра
# 182        188               спортивная школа челябинская область
# 150        155  спортивный клуб ростовская областная федерация...
# 277        286  спортивный клуб фигурного катания ice prestige...
# 263        272  спортивный клуб фигурного катания open ice сан...
# 100        105  спортивный клуб фигурного катания т москвиной ...
# 162        167               ставрополь арена ставропольский край
# 163        168                                старт пермский край
# 164        169                         старт свердловская область
# 165        170                           стартайс санкт петербург
# 166        171                                     столица москва
# 167        172                        стрела республика татарстан
# 215        222                              темпо санкт петербург
# 216        223                              титул санкт петербург
# 217        224                          тодес челябинская область
# 16          17             топ тим лучшая команда санкт петербург
# 218        225                               триумф пермский край
# 221        228  удмуртская федерация фигурного катания удмуртс...
# 219        226                     ужный урал челябинская область
# 220        227    училище олимпийского резерва московская область
# 222        229                            фаворит санкт петербург
# 223        230  фау московская область российской федерации це...
# 224        231  федерация фигурного катания на коньках калинин...
# 230        237  федерация фигурного катания на коньках республ...
# 232        239  федерация фигурного катания на коньках рк респ...
# 235        242  федерация фигурного катания на коньках ставроп...
# 231        238   федерация фигурного катания на коньках хмао югра
# 233        240  федерация фигурного катания на коньках янао ям...
# 228        235  федерация фигурного катания рб республика башк...
# 229        236  федерация фигурного катания спортивный клуб ст...
# 227        234       федерация фигурного катания тверская область
# 225        232      фигурного катания на коньках тверская область
# 226        233  физкультурно оздоровительный комплекс городец ...
# 234        241                        ффккво владимирская область
# 151        156                 хоккейный клуб ска санкт петербург
# 236        243                   холмск арена сахалинская область
# 238        245              хрустальный конек воронежская область
# 237        244                                 хрустальный москва
# 242        249    центр зимних видов спорта новосибирская область
# 239        246     центр по летним видам спорта красноярский край
# 240        247                       центр развития спорта москва
# 241        248     центр спортивных технологий московская область
# 247        254  центр физической культуры, спорта и здоровья в...
# 246        253  центр физической культуры, спорта и здоровья к...
# 248        256  центр физической культуры, спорта и здоровья м...
# 261        270  центр физической культуры, спорта и здоровья н...
# 249        257  центр физической культуры, спорта и здоровья ф...
# 245        252  центральный спортивный клуб армии им с а жука ...
# 244        251           центральный спортивный клуб армии москва
# 243        250  цоп по фигурному катанию на коньках санкт пете...
# 250        258                             челны набережные челны
# 251        259                            чемпион санкт петербург
# 286        297              чудо дюсош сияние воронежская область
# 23          24  школа фигурного катания е бережной санкт петер...
# 271        280                       энергия льда санкт петербург
# 252        260                       энергия свердловская область
# 253        261                   южное сияние челябинская область
# 254        262                                   южный лед москва
# 255        263                          юность мурманская область
# 256        264                        юность свердловская область
# 257        265                                   юность хмао югра
# 258        266                        юность чувашская республика
# 259        267               ямал ямало ненецкий автономный округ

# %% [markdown]
# Почистим данные:

# %%
def remove_non_meaningful(text):
    text = re.sub(r'\b\w{1,1}\b', '', text)  # Удаляем слова длиной менее 2 символов
    text = re.sub(r'\s+', ' ', text).strip()  # Удаляем лишние пробелы
    return text

df_train['name'] = df_train['name'].apply(remove_non_meaningful)
df_test['name'] = df_test['name'].apply(remove_non_meaningful)

# %%
display(df_train.head(10))
# Out:
#    school_id                                            name
# 0          1                     авангард московская область
# 1          2        авангард ямало ненецкий автономный округ
# 2          3                    авиатор республика татарстан
# 3          4                          аврора санкт петербург
# 4          5              ice dream айс дрим санкт петербург
# 5          6                         айсберг республика крым
# 6          7                       айсберг рязанская область
# 7          8                    айсберг свердловская область
# 8          9                          звездочка северодвинск
# 9         10  академия синхронного катания на коньках москва

# %% [markdown]
# Для удобства переименуем название колонки в тесте:

# %%
df_test = df_test.rename(columns={'name':'name_variant'}).sort_values(by='school_id')
df_test
# Out:
#      school_id                                       name_variant
# 887          1       московская область спортивная школа авангард
# 886          2                     янао спортивная школа авангард
# 884          3  спортивная школа олимпийского резерва фсо авиа...
# 883          3  республика татарстан спортивная школа олимпийс...
# 882          3  республика татарстан муниципальное бюджетное у...
# ..         ...                                                ...
# 4          609                          спортивная школа гвоздика
# 3          610  саратовская область государственное бюджетное ...
# 2          610  спортивная школа олимпийского резерва надежда ...
# 1         1836                      москва спортивный клуб триумф
# 0         1836      общество ограниченной ответственностью триумф
#
# [888 rows x 2 columns]

# %% [markdown]
# ## 3. Преобразование тренировочной выборки (аугментация)

# %% [markdown]
# Увеличим размер выборки с помощью аугментации для того чтобы в дальнейшем дообучить модель. Напишем функцию, которая сформирует новый датасет путем добавления строк дубликатов с ошибками и переменой слов местами для последующего дообучения модели:

# %%
def augment_data(df):
    augmented_data = []

    for i in range(len(df)):
        original_name = df.loc[i, 'name']
        school_id = df.loc[i, 'school_id']

        for _ in range(7):  # Создаем 7 дубликатов с ошибками
            words = original_name.split()
            random_word_index = random.randint(0, len(words) - 1)
            new_words = words.copy()
            error_index = random.randint(0, len(new_words[random_word_index]) - 1)
            new_words[random_word_index] = list(new_words[random_word_index])
            new_words[random_word_index][error_index] = chr(np.random.randint(1072, 1103))
            new_word = ''.join(new_words[random_word_index])
            words[random_word_index] = new_word
            random.shuffle(words)
                                  
            augmented_name = ' '.join(words)
            augmented_data.append({'name': original_name, 'aug_name': augmented_name, 'school_id': school_id})
            
            

    augmented_df = pd.DataFrame(augmented_data)
    return augmented_df

df_train_aug = augment_data(df_train)
df_train_aug = df_train_aug
display(df_train_aug)
# Out:
#                                                    name  \
# 0                           авангард московская область
# 1                           авангард московская область
# 2                           авангард московская область
# 3                           авангард московская область
# 4                           авангард московская область
# ...                                                 ...
# 2088  общество ограниченной ответственностью триумф ...
# 2089  общество ограниченной ответственностью триумф ...
# 2090  общество ограниченной ответственностью триумф ...
# 2091  общество ограниченной ответственностью триумф ...
# 2092  общество ограниченной ответственностью триумф ...
#
#                                                aug_name  school_id
# 0                           обхасть авангард московская          1
# 1                           авангард москцвская область          1
# 2                           московская авангагд область          1
# 3                           область московткая авангард          1
# 4                           московская обкасть авангард          1
# ...                                                 ...        ...
# 2088  общество ответственноатью триумф москва ограни...       1836
# 2089  москва ответственностью ограниченной тлиумф об...       1836
# 2090  обществг триумф ограниченной ответственностью ...       1836
# 2091  обществы ответственностью ограниченной триумф ...       1836
# 2092  общество москта ответственностью триумф ограни...       1836
#
# [2093 rows x 3 columns]

# %%
df_train_aug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       2093 non-null   object
#  1   aug_name   2093 non-null   object
#  2   school_id  2093 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 49.2+ KB

# %% [markdown]
# ## 4. Обучение модели

# %% [markdown]
# ### Модель №1: (sentence-transformers) LaBSE

# %%
model_1 = SentenceTransformer('sentence-transformers/LaBSE')

# %%
corpuse_embedding_1 = model_1.encode(df_train.name.values)

# %%
corpuse_embedding_1
# Out:
# array([[ 0.04227928,  0.02789917,  0.02638606, ..., -0.03887578,
#         -0.06346413, -0.05755835],
#        [ 0.03132331,  0.01584869,  0.04261846, ..., -0.04308641,
#         -0.03137583, -0.01525755],
#        [ 0.01162198, -0.03974545,  0.00175533, ...,  0.02332445,
#          0.06898228,  0.05103588],
#        ...,
#        [ 0.0181281 , -0.03543217,  0.01988792, ..., -0.01726287,
#          0.02678434, -0.03435838],
#        [ 0.06397197,  0.01384863,  0.0186362 , ..., -0.01232259,
#          0.03450641, -0.00033415],
#        [-0.00088473, -0.00694319,  0.03504249, ..., -0.04329306,
#          0.0427042 , -0.03005286]], dtype=float32)

# %%
query_embedding_1 = model_1.encode(df_test.name_variant.values)

# %%
query_embedding_1
# Out:
# array([[ 0.03133927,  0.01080929,  0.00775494, ..., -0.04476377,
#         -0.04485656, -0.05191057],
#        [ 0.00269639,  0.0041837 ,  0.00678373, ..., -0.02626428,
#         -0.06016866, -0.0615179 ],
#        [ 0.00240553, -0.04714845, -0.0313983 , ..., -0.02556991,
#          0.01677923,  0.03900205],
#        ...,
#        [ 0.00153687, -0.00443714,  0.01859644, ..., -0.01346344,
#          0.00155952, -0.02998321],
#        [ 0.02594607,  0.01444612,  0.01639306, ..., -0.04595377,
#         -0.01468683, -0.03568109],
#        [-0.00775135, -0.00167825,  0.04449824, ..., -0.00327478,
#          0.04104581, -0.04078319]], dtype=float32)

# %%
result = util.semantic_search(query_embedding_1, corpuse_embedding_1, top_k=3)

# %%
result
# Out:
# [[{'corpus_id': 0, 'score': 0.787702739238739},
#   {'corpus_id': 178, 'score': 0.7783902883529663},
#   {'corpus_id': 204, 'score': 0.768876314163208}],
#  [{'corpus_id': 168, 'score': 0.6131557822227478},
#   {'corpus_id': 178, 'score': 0.6087374091148376},
#   {'corpus_id': 55, 'score': 0.5879767537117004}],
#  [{'corpus_id': 195, 'score': 0.8954892158508301},
#   {'corpus_id': 138, 'score': 0.8549620509147644},
#   {'corpus_id': 199, 'score': 0.7830220460891724}],
#  [{'corpus_id': 195, 'score': 0.9000043272972107},
#   {'corpus_id': 138, 'score': 0.8760614395141602},
#   {'corpus_id': 199, 'score': 0.7711621522903442}],
#  [{'corpus_id': 138, 'score': 0.8316155076026917},
#   {'corpus_id': 195, 'score': 0.8158401846885681},
#   {'corpus_id': 94, 'score': 0.7448347210884094}],
#  [{'corpus_id': 138, 'score': 0.850380539894104},
#   {'corpus_id': 195, 'score': 0.8324564695358276},
#   {'corpus_id': 94, 'score': 0.7663852572441101}],
#  [{'corpus_id': 138, 'score': 0.8321430087089539},
#   {'corpus_id': 195, 'score': 0.8163647651672363},
#   {'corpus_id': 35, 'score': 0.8139477968215942}],
#  [{'corpus_id': 20, 'score': 0.7290381193161011},
#   {'corpus_id': 102, 'score': 0.66978919506073},
#   {'corpus_id': 66, 'score': 0.657072126865387}],
#  [{'corpus_id': 229, 'score': 0.6284630298614502},
#   {'corpus_id': 173, 'score': 0.6231377124786377},
#   {'corpus_id': 227, 'score': 0.6195765733718872}],
#  [{'corpus_id': 4, 'score': 0.37235379219055176},
#   {'corpus_id': 5, 'score': 0.3721552789211273},
#   {'corpus_id': 110, 'score': 0.3539436161518097}],
#  [{'corpus_id': 165, 'score': 0.8606629371643066},
#   {'corpus_id': 129, 'score': 0.8552528023719788},
#   {'corpus_id': 264, 'score': 0.8528550863265991}],
#  [{'corpus_id': 102, 'score': 0.6932841539382935},
#   {'corpus_id': 20, 'score': 0.6864120960235596},
#   {'corpus_id': 175, 'score': 0.6793549656867981}],
#  [{'corpus_id': 102, 'score': 0.6901543140411377},
#   {'corpus_id': 20, 'score': 0.6844735741615295},
#   {'corpus_id': 175, 'score': 0.6748974323272705}],
#  [{'corpus_id': 5, 'score': 0.9048777222633362},
#   {'corpus_id': 64, 'score': 0.6067075133323669},
#   {'corpus_id': 6, 'score': 0.5672869086265564}],
#  [{'corpus_id': 289, 'score': 0.7995980978012085},
#   {'corpus_id': 68, 'score': 0.7893216609954834},
#   {'corpus_id': 260, 'score': 0.7861270308494568}],
#  [{'corpus_id': 289, 'score': 0.8252259492874146},
#   {'corpus_id': 34, 'score': 0.7729014158248901},
#   {'corpus_id': 210, 'score': 0.772170901298523}],
#  [{'corpus_id': 210, 'score': 0.8543822169303894},
#   {'corpus_id': 6, 'score': 0.793345034122467},
#   {'corpus_id': 169, 'score': 0.7610862255096436}],
#  [{'corpus_id': 180, 'score': 0.8014047741889954},
#   {'corpus_id': 7, 'score': 0.7796414494514465},
#   {'corpus_id': 107, 'score': 0.7395268082618713}],
#  [{'corpus_id': 8, 'score': 0.6881281733512878},
#   {'corpus_id': 58, 'score': 0.5951560735702515},
#   {'corpus_id': 75, 'score': 0.5436077117919922}],
#  [{'corpus_id': 8, 'score': 1.0000003576278687},
#   {'corpus_id': 145, 'score': 0.8140967488288879},
#   {'corpus_id': 58, 'score': 0.6338536739349365}],
#  [{'corpus_id': 9, 'score': 0.9545228481292725},
#   {'corpus_id': 92, 'score': 0.8512274622917175},
#   {'corpus_id': 102, 'score': 0.7830818295478821}],
#  [{'corpus_id': 282, 'score': 0.760399341583252},
#   {'corpus_id': 281, 'score': 0.6738104224205017},
#   {'corpus_id': 287, 'score': 0.6700459122657776}],
#  [{'corpus_id': 35, 'score': 0.8311589956283569},
#   {'corpus_id': 285, 'score': 0.8204659819602966},
#   {'corpus_id': 196, 'score': 0.8160563707351685}],
#  [{'corpus_id': 10, 'score': 0.9142490029335022},
#   {'corpus_id': 196, 'score': 0.9103413224220276},
#   {'corpus_id': 191, 'score': 0.8992374539375305}],
#  [{'corpus_id': 93, 'score': 0.807675838470459},
#   {'corpus_id': 91, 'score': 0.7952184081077576},
#   {'corpus_id': 68, 'score': 0.7889217734336853}],
#  [{'corpus_id': 95, 'score': 0.799225926399231},
#   {'corpus_id': 94, 'score': 0.7738866209983826},
#   {'corpus_id': 193, 'score': 0.7620487809181213}],
#  [{'corpus_id': 290, 'score': 0.8099421858787537},
#   {'corpus_id': 95, 'score': 0.8046749234199524},
#   {'corpus_id': 204, 'score': 0.7742459774017334}],
#  [{'corpus_id': 204, 'score': 0.8013595342636108},
#   {'corpus_id': 205, 'score': 0.8006491661071777},
#   {'corpus_id': 220, 'score': 0.7976033687591553}],
#  [{'corpus_id': 282, 'score': 0.7461420893669128},
#   {'corpus_id': 92, 'score': 0.7161955237388611},
#   {'corpus_id': 276, 'score': 0.7014914155006409}],
#  [{'corpus_id': 92, 'score': 0.7804208397865295},
#   {'corpus_id': 9, 'score': 0.7221124768257141},
#   {'corpus_id': 14, 'score': 0.70064377784729}],
#  [{'corpus_id': 282, 'score': 0.7600982785224915},
#   {'corpus_id': 92, 'score': 0.7431998252868652},
#   {'corpus_id': 9, 'score': 0.6916789412498474}],
#  [{'corpus_id': 292, 'score': 0.7223681211471558},
#   {'corpus_id': 298, 'score': 0.6955683827400208},
#   {'corpus_id': 14, 'score': 0.6666551232337952}],
#  [{'corpus_id': 292, 'score': 0.7223681211471558},
#   {'corpus_id': 298, 'score': 0.6955683827400208},
#   {'corpus_id': 14, 'score': 0.6666551232337952}],
#  [{'corpus_id': 282, 'score': 0.7600982785224915},
#   {'corpus_id': 92, 'score': 0.7431998252868652},
#   {'corpus_id': 9, 'score': 0.6916789412498474}],
#  [{'corpus_id': 282, 'score': 0.7600982785224915},
#   {'corpus_id': 92, 'score': 0.7431998252868652},
#   {'corpus_id': 9, 'score': 0.6916789412498474}],
#  [{'corpus_id': 15, 'score': 0.7623916864395142},
#   {'corpus_id': 292, 'score': 0.7028553485870361},
#   {'corpus_id': 298, 'score': 0.6690182089805603}],
#  [{'corpus_id': 92, 'score': 0.7720857858657837},
#   {'corpus_id': 102, 'score': 0.7490630745887756},
#   {'corpus_id': 20, 'score': 0.7194411754608154}],
#  [{'corpus_id': 15, 'score': 0.9311667680740356},
#   {'corpus_id': 14, 'score': 0.7891113758087158},
#   {'corpus_id': 88, 'score': 0.6812218427658081}],
#  [{'corpus_id': 16, 'score': 0.6150370836257935},
#   {'corpus_id': 282, 'score': 0.5687471032142639},
#   {'corpus_id': 287, 'score': 0.5627175569534302}],
#  [{'corpus_id': 287, 'score': 0.6175389885902405},
#   {'corpus_id': 282, 'score': 0.6035664677619934},
#   {'corpus_id': 281, 'score': 0.5360303521156311}],
#  [{'corpus_id': 17, 'score': 0.8410786390304565},
#   {'corpus_id': 52, 'score': 0.8069846034049988},
#   {'corpus_id': 201, 'score': 0.7887188792228699}],
#  [{'corpus_id': 93, 'score': 0.794365406036377},
#   {'corpus_id': 104, 'score': 0.779556155204773},
#   {'corpus_id': 34, 'score': 0.7427704930305481}],
#  [{'corpus_id': 55, 'score': 0.6760588884353638},
#   {'corpus_id': 168, 'score': 0.6751638650894165},
#   {'corpus_id': 295, 'score': 0.6220941543579102}],
#  [{'corpus_id': 244, 'score': 0.8704401850700378},
#   {'corpus_id': 19, 'score': 0.861388087272644},
#   {'corpus_id': 92, 'score': 0.8322438597679138}],
#  [{'corpus_id': 244, 'score': 0.8704401850700378},
#   {'corpus_id': 19, 'score': 0.861388087272644},
#   {'corpus_id': 92, 'score': 0.8322438597679138}],
#  [{'corpus_id': 282, 'score': 0.8259544968605042},
#   {'corpus_id': 244, 'score': 0.7934601306915283},
#   {'corpus_id': 92, 'score': 0.7538232207298279}],
#  [{'corpus_id': 20, 'score': 0.8783940076828003},
#   {'corpus_id': 244, 'score': 0.8454000353813171},
#   {'corpus_id': 150, 'score': 0.825086236000061}],
#  [{'corpus_id': 282, 'score': 0.8016889095306396},
#   {'corpus_id': 20, 'score': 0.7899451851844788},
#   {'corpus_id': 150, 'score': 0.7702975869178772}],
#  [{'corpus_id': 20, 'score': 0.8521814942359924},
#   {'corpus_id': 150, 'score': 0.8240060806274414},
#   {'corpus_id': 223, 'score': 0.8227939009666443}],
#  [{'corpus_id': 21, 'score': 0.7218065857887268},
#   {'corpus_id': 233, 'score': 0.7193329334259033},
#   {'corpus_id': 224, 'score': 0.6699703335762024}],
#  [{'corpus_id': 285, 'score': 0.8457517027854919},
#   {'corpus_id': 35, 'score': 0.8293276429176331},
#   {'corpus_id': 95, 'score': 0.8019937872886658}],
#  [{'corpus_id': 178, 'score': 0.8505866527557373},
#   {'corpus_id': 48, 'score': 0.7962519526481628},
#   {'corpus_id': 22, 'score': 0.7860769629478455}],
#  [{'corpus_id': 281, 'score': 0.7844268083572388},
#   {'corpus_id': 68, 'score': 0.747602105140686},
#   {'corpus_id': 93, 'score': 0.7081305980682373}],
#  [{'corpus_id': 281, 'score': 0.7462350726127625},
#   {'corpus_id': 282, 'score': 0.6928358674049377},
#   {'corpus_id': 93, 'score': 0.6442596912384033}],
#  [{'corpus_id': 23, 'score': 0.8519939184188843},
#   {'corpus_id': 276, 'score': 0.8115034699440002},
#   {'corpus_id': 192, 'score': 0.7860020399093628}],
#  [{'corpus_id': 281, 'score': 0.6902751326560974},
#   {'corpus_id': 282, 'score': 0.6444672346115112},
#   {'corpus_id': 93, 'score': 0.6033972501754761}],
#  [{'corpus_id': 281, 'score': 0.7462350726127625},
#   {'corpus_id': 282, 'score': 0.6928358674049377},
#   {'corpus_id': 93, 'score': 0.6442596912384033}],
#  [{'corpus_id': 281, 'score': 0.6902751326560974},
#   {'corpus_id': 282, 'score': 0.6444672346115112},
#   {'corpus_id': 93, 'score': 0.6033972501754761}],
#  [{'corpus_id': 23, 'score': 0.7965391874313354},
#   {'corpus_id': 276, 'score': 0.7771066427230835},
#   {'corpus_id': 192, 'score': 0.7374905347824097}],
#  [{'corpus_id': 281, 'score': 0.7099002599716187},
#   {'corpus_id': 282, 'score': 0.6557015180587769},
#   {'corpus_id': 287, 'score': 0.6326047778129578}],
#  [{'corpus_id': 281, 'score': 0.7099002599716187},
#   {'corpus_id': 282, 'score': 0.6557015180587769},
#   {'corpus_id': 287, 'score': 0.6326047778129578}],
#  [{'corpus_id': 34, 'score': 0.9821164011955261},
#   {'corpus_id': 91, 'score': 0.792285680770874},
#   {'corpus_id': 93, 'score': 0.7570512294769287}],
#  [{'corpus_id': 34, 'score': 0.9706932902336121},
#   {'corpus_id': 91, 'score': 0.7704377174377441},
#   {'corpus_id': 173, 'score': 0.7685157656669617}],
#  [{'corpus_id': 34, 'score': 0.8504602909088135},
#   {'corpus_id': 173, 'score': 0.8090400695800781},
#   {'corpus_id': 281, 'score': 0.7931044101715088}],
#  [{'corpus_id': 173, 'score': 0.8504433035850525},
#   {'corpus_id': 34, 'score': 0.8165285587310791},
#   {'corpus_id': 150, 'score': 0.6984347701072693}],
#  [{'corpus_id': 34, 'score': 0.8504602909088135},
#   {'corpus_id': 173, 'score': 0.8090400695800781},
#   {'corpus_id': 281, 'score': 0.7931044101715088}],
#  [{'corpus_id': 173, 'score': 0.8504433035850525},
#   {'corpus_id': 34, 'score': 0.8165285587310791},
#   {'corpus_id': 150, 'score': 0.6984347701072693}],
#  [{'corpus_id': 34, 'score': 0.8820275068283081},
#   {'corpus_id': 173, 'score': 0.8714199066162109},
#   {'corpus_id': 150, 'score': 0.7978098392486572}],
#  [{'corpus_id': 281, 'score': 0.7717750072479248},
#   {'corpus_id': 68, 'score': 0.7328621745109558},
#   {'corpus_id': 260, 'score': 0.7121896147727966}],
#  [{'corpus_id': 281, 'score': 0.7717750072479248},
#   {'corpus_id': 68, 'score': 0.7328621745109558},
#   {'corpus_id': 260, 'score': 0.7121896147727966}],
#  [{'corpus_id': 23, 'score': 0.7474135756492615},
#   {'corpus_id': 54, 'score': 0.7464554309844971},
#   {'corpus_id': 192, 'score': 0.7432126402854919}],
#  [{'corpus_id': 68, 'score': 0.6810029149055481},
#   {'corpus_id': 260, 'score': 0.6671047210693359},
#   {'corpus_id': 281, 'score': 0.6665027737617493}],
#  [{'corpus_id': 281, 'score': 0.7717750072479248},
#   {'corpus_id': 68, 'score': 0.7328621745109558},
#   {'corpus_id': 260, 'score': 0.7121896147727966}],
#  [{'corpus_id': 281, 'score': 0.7717750072479248},
#   {'corpus_id': 68, 'score': 0.7328621745109558},
#   {'corpus_id': 260, 'score': 0.7121896147727966}],
#  [{'corpus_id': 92, 'score': 0.826631486415863},
#   {'corpus_id': 204, 'score': 0.7886090278625488},
#   {'corpus_id': 194, 'score': 0.7878636121749878}],
#  [{'corpus_id': 290, 'score': 0.7485042810440063},
#   {'corpus_id': 92, 'score': 0.7414703965187073},
#   {'corpus_id': 285, 'score': 0.7186175584793091}],
#  [{'corpus_id': 290, 'score': 0.754525899887085},
#   {'corpus_id': 285, 'score': 0.7542592287063599},
#   {'corpus_id': 92, 'score': 0.7430386543273926}],
#  [{'corpus_id': 92, 'score': 0.8994125127792358},
#   {'corpus_id': 9, 'score': 0.8039306998252869},
#   {'corpus_id': 102, 'score': 0.7897143363952637}],
#  [{'corpus_id': 92, 'score': 0.7942355275154114},
#   {'corpus_id': 290, 'score': 0.7511609792709351},
#   {'corpus_id': 102, 'score': 0.7107579708099365}],
#  [{'corpus_id': 26, 'score': 0.8125725984573364},
#   {'corpus_id': 240, 'score': 0.6279438734054565},
#   {'corpus_id': 244, 'score': 0.5996333360671997}],
#  [{'corpus_id': 290, 'score': 0.7485042810440063},
#   {'corpus_id': 92, 'score': 0.7414703965187073},
#   {'corpus_id': 285, 'score': 0.7186175584793091}],
#  [{'corpus_id': 92, 'score': 0.805350661277771},
#   {'corpus_id': 290, 'score': 0.75194251537323},
#   {'corpus_id': 102, 'score': 0.7215588688850403}],
#  [{'corpus_id': 292, 'score': 0.5934341549873352},
#   {'corpus_id': 298, 'score': 0.5510900020599365},
#   {'corpus_id': 282, 'score': 0.4522303342819214}],
#  [{'corpus_id': 176, 'score': 0.8408984541893005},
#   {'corpus_id': 33, 'score': 0.831157922744751},
#   {'corpus_id': 209, 'score': 0.8185470104217529}],
#  [{'corpus_id': 33, 'score': 0.7450599670410156},
#   {'corpus_id': 209, 'score': 0.7235373854637146},
#   {'corpus_id': 176, 'score': 0.7102838754653931}],
#  [{'corpus_id': 34, 'score': 0.6415637731552124},
#   {'corpus_id': 229, 'score': 0.6380477547645569},
#   {'corpus_id': 276, 'score': 0.6277391314506531}],
#  [{'corpus_id': 200, 'score': 0.9440731406211853},
#   {'corpus_id': 205, 'score': 0.8475464582443237},
#   {'corpus_id': 189, 'score': 0.8331267833709717}],
#  [{'corpus_id': 95, 'score': 0.8404847383499146},
#   {'corpus_id': 94, 'score': 0.83614581823349},
#   {'corpus_id': 200, 'score': 0.8264883756637573}],
#  [{'corpus_id': 92, 'score': 0.7731119394302368},
#   {'corpus_id': 9, 'score': 0.6886309385299683},
#   {'corpus_id': 102, 'score': 0.675958514213562}],
#  [{'corpus_id': 33, 'score': 0.8652912378311157},
#   {'corpus_id': 35, 'score': 0.8275575637817383},
#   {'corpus_id': 94, 'score': 0.80243980884552}],
#  [{'corpus_id': 33, 'score': 1.0},
#   {'corpus_id': 197, 'score': 0.8710776567459106},
#   {'corpus_id': 188, 'score': 0.8702832460403442}],
#  [{'corpus_id': 33, 'score': 0.8819136023521423},
#   {'corpus_id': 35, 'score': 0.8399563431739807},
#   {'corpus_id': 94, 'score': 0.8115230798721313}],
#  [{'corpus_id': 33, 'score': 0.8954482078552246},
#   {'corpus_id': 35, 'score': 0.8170711398124695},
#   {'corpus_id': 188, 'score': 0.7894468903541565}],
#  [{'corpus_id': 33, 'score': 0.9954745173454285},
#   {'corpus_id': 188, 'score': 0.8660251498222351},
#   {'corpus_id': 197, 'score': 0.8653696179389954}],
#  [{'corpus_id': 33, 'score': 0.8954482078552246},
#   {'corpus_id': 35, 'score': 0.8170711398124695},
#   {'corpus_id': 188, 'score': 0.7894468903541565}],
#  [{'corpus_id': 33, 'score': 0.9552406668663025},
#   {'corpus_id': 197, 'score': 0.840704083442688},
#   {'corpus_id': 188, 'score': 0.8302372097969055}],
#  [{'corpus_id': 34, 'score': 1.0000004768371582},
#   {'corpus_id': 91, 'score': 0.8200051784515381},
#   {'corpus_id': 93, 'score': 0.7816072702407837}],
#  [{'corpus_id': 35, 'score': 0.9614877700805664},
#   {'corpus_id': 188, 'score': 0.8007717132568359},
#   {'corpus_id': 285, 'score': 0.7864585518836975}],
#  [{'corpus_id': 35, 'score': 0.944539487361908},
#   {'corpus_id': 188, 'score': 0.8559096455574036},
#   {'corpus_id': 94, 'score': 0.8544902801513672}],
#  [{'corpus_id': 35, 'score': 0.9874733090400696},
#   {'corpus_id': 188, 'score': 0.8392919301986694},
#   {'corpus_id': 285, 'score': 0.8122403621673584}],
#  [{'corpus_id': 35, 'score': 0.9716058969497681},
#   {'corpus_id': 188, 'score': 0.8285782337188721},
#   {'corpus_id': 285, 'score': 0.8049108982086182}],
#  [{'corpus_id': 35, 'score': 0.892190158367157},
#   {'corpus_id': 188, 'score': 0.799187183380127},
#   {'corpus_id': 94, 'score': 0.7770182490348816}],
#  [{'corpus_id': 35, 'score': 0.9685417413711548},
#   {'corpus_id': 188, 'score': 0.8206784129142761},
#   {'corpus_id': 285, 'score': 0.8112567663192749}],
#  [{'corpus_id': 35, 'score': 0.93376225233078},
#   {'corpus_id': 188, 'score': 0.8608149886131287},
#   {'corpus_id': 94, 'score': 0.8399235010147095}],
#  [{'corpus_id': 54, 'score': 0.8090803623199463},
#   {'corpus_id': 265, 'score': 0.7952003479003906},
#   {'corpus_id': 49, 'score': 0.7798547744750977}],
#  [{'corpus_id': 56, 'score': 0.7447042465209961},
#   {'corpus_id': 176, 'score': 0.7420088052749634},
#   {'corpus_id': 48, 'score': 0.7409945726394653}],
#  [{'corpus_id': 52, 'score': 0.6876587271690369},
#   {'corpus_id': 260, 'score': 0.6812549829483032},
#   {'corpus_id': 48, 'score': 0.6675868630409241}],
#  [{'corpus_id': 52, 'score': 0.6876587271690369},
#   {'corpus_id': 260, 'score': 0.6812549829483032},
#   {'corpus_id': 48, 'score': 0.6675868630409241}],
#  [{'corpus_id': 52, 'score': 0.6876587271690369},
#   {'corpus_id': 260, 'score': 0.6812549829483032},
#   {'corpus_id': 48, 'score': 0.6675868630409241}],
#  [{'corpus_id': 52, 'score': 0.6876587271690369},
#   {'corpus_id': 260, 'score': 0.6812549829483032},
#   {'corpus_id': 48, 'score': 0.6675868630409241}],
#  [{'corpus_id': 37, 'score': 0.8105049133300781},
#   {'corpus_id': 124, 'score': 0.6750248074531555},
#   {'corpus_id': 65, 'score': 0.6590768098831177}],
#  [{'corpus_id': 35, 'score': 0.8330979347229004},
#   {'corpus_id': 285, 'score': 0.8000482320785522},
#   {'corpus_id': 95, 'score': 0.7978682518005371}],
#  [{'corpus_id': 95, 'score': 0.8137420415878296},
#   {'corpus_id': 94, 'score': 0.7907435297966003},
#   {'corpus_id': 35, 'score': 0.7646307945251465}],
#  [{'corpus_id': 205, 'score': 0.8116172552108765},
#   {'corpus_id': 209, 'score': 0.8006210327148438},
#   {'corpus_id': 201, 'score': 0.7987886667251587}],
#  [{'corpus_id': 205, 'score': 0.8116172552108765},
#   {'corpus_id': 209, 'score': 0.8006210327148438},
#   {'corpus_id': 201, 'score': 0.7987886667251587}],
#  [{'corpus_id': 285, 'score': 0.8448631763458252},
#   {'corpus_id': 95, 'score': 0.8113266825675964},
#   {'corpus_id': 68, 'score': 0.7956822514533997}],
#  [{'corpus_id': 285, 'score': 0.8506924510002136},
#   {'corpus_id': 260, 'score': 0.8286615014076233},
#   {'corpus_id': 95, 'score': 0.7997819185256958}],
#  [{'corpus_id': 50, 'score': 0.8157075643539429},
#   {'corpus_id': 56, 'score': 0.7960361242294312},
#   {'corpus_id': 52, 'score': 0.7786777019500732}],
#  [{'corpus_id': 285, 'score': 0.8796349167823792},
#   {'corpus_id': 260, 'score': 0.8484250903129578},
#   {'corpus_id': 35, 'score': 0.8270348906517029}],
#  [{'corpus_id': 39, 'score': 0.8891661763191223},
#   {'corpus_id': 124, 'score': 0.7987176775932312},
#   {'corpus_id': 88, 'score': 0.7792761921882629}],
#  [{'corpus_id': 281, 'score': 0.8102720975875854},
#   {'corpus_id': 282, 'score': 0.7177305221557617},
#   {'corpus_id': 40, 'score': 0.7104272842407227}],
#  [{'corpus_id': 41, 'score': 0.9162893295288086},
#   {'corpus_id': 103, 'score': 0.8073277473449707},
#   {'corpus_id': 42, 'score': 0.6945702433586121}],
#  [{'corpus_id': 41, 'score': 0.8214678168296814},
#   {'corpus_id': 103, 'score': 0.7428145408630371},
#   {'corpus_id': 42, 'score': 0.6577426791191101}],
#  [{'corpus_id': 41, 'score': 0.9065466523170471},
#   {'corpus_id': 56, 'score': 0.8661312460899353},
#   {'corpus_id': 176, 'score': 0.7780535817146301}],
#  [{'corpus_id': 285, 'score': 0.8964982032775879},
#   {'corpus_id': 35, 'score': 0.8681066632270813},
#   {'corpus_id': 260, 'score': 0.8430742025375366}],
#  [{'corpus_id': 42, 'score': 0.8091169595718384},
#   {'corpus_id': 178, 'score': 0.7950782775878906},
#   {'corpus_id': 260, 'score': 0.7529622316360474}],
#  [{'corpus_id': 43, 'score': 0.9440333843231201},
#   {'corpus_id': 234, 'score': 0.8465973734855652},
#   {'corpus_id': 44, 'score': 0.7419833540916443}],
#  [{'corpus_id': 43, 'score': 0.9158602952957153},
#   {'corpus_id': 234, 'score': 0.8530046939849854},
#   {'corpus_id': 41, 'score': 0.7423874735832214}],
#  [{'corpus_id': 43, 'score': 0.9158602952957153},
#   {'corpus_id': 234, 'score': 0.8530046939849854},
#   {'corpus_id': 41, 'score': 0.7423874735832214}],
#  [{'corpus_id': 44, 'score': 0.8873501420021057},
#   {'corpus_id': 43, 'score': 0.6331035494804382},
#   {'corpus_id': 122, 'score': 0.528298020362854}],
#  [{'corpus_id': 44, 'score': 0.9431792497634888},
#   {'corpus_id': 43, 'score': 0.7507284283638},
#   {'corpus_id': 234, 'score': 0.6297298669815063}],
#  [{'corpus_id': 44, 'score': 0.8818957805633545},
#   {'corpus_id': 43, 'score': 0.6215982437133789},
#   {'corpus_id': 122, 'score': 0.5638747215270996}],
#  [{'corpus_id': 211, 'score': 0.6332663893699646},
#   {'corpus_id': 190, 'score': 0.6283960938453674},
#   {'corpus_id': 83, 'score': 0.6180652379989624}],
#  [{'corpus_id': 192, 'score': 0.8264644145965576},
#   {'corpus_id': 277, 'score': 0.8126794099807739},
#   {'corpus_id': 263, 'score': 0.809115469455719}],
#  [{'corpus_id': 268, 'score': 0.6481165885925293},
#   {'corpus_id': 229, 'score': 0.6026827692985535},
#   {'corpus_id': 231, 'score': 0.5896615386009216}],
#  [{'corpus_id': 268, 'score': 0.9242367148399353},
#   {'corpus_id': 280, 'score': 0.81295245885849},
#   {'corpus_id': 243, 'score': 0.7987524271011353}],
#  [{'corpus_id': 268, 'score': 0.7291555404663086},
#   {'corpus_id': 276, 'score': 0.6373208165168762},
#   {'corpus_id': 229, 'score': 0.5968643426895142}],
#  [{'corpus_id': 44, 'score': 0.5029869079589844},
#   {'corpus_id': 114, 'score': 0.43644943833351135},
#   {'corpus_id': 43, 'score': 0.42931970953941345}],
#  [{'corpus_id': 45, 'score': 0.9051402807235718},
#   {'corpus_id': 268, 'score': 0.8636518716812134},
#   {'corpus_id': 280, 'score': 0.7856980562210083}],
#  [{'corpus_id': 268, 'score': 0.963723361492157},
#   {'corpus_id': 45, 'score': 0.8696017265319824},
#   {'corpus_id': 243, 'score': 0.818729817867279}],
#  [{'corpus_id': 45, 'score': 0.9051402807235718},
#   {'corpus_id': 268, 'score': 0.8636518716812134},
#   {'corpus_id': 280, 'score': 0.7856980562210083}],
#  [{'corpus_id': 268, 'score': 0.9242367148399353},
#   {'corpus_id': 280, 'score': 0.81295245885849},
#   {'corpus_id': 243, 'score': 0.7987524271011353}],
#  [{'corpus_id': 268, 'score': 0.7411475777626038},
#   {'corpus_id': 277, 'score': 0.7005792856216431},
#   {'corpus_id': 192, 'score': 0.6847859025001526}],
#  [{'corpus_id': 211, 'score': 0.6557655930519104},
#   {'corpus_id': 214, 'score': 0.628273069858551},
#   {'corpus_id': 189, 'score': 0.6247802972793579}],
#  [{'corpus_id': 268, 'score': 0.9242367148399353},
#   {'corpus_id': 280, 'score': 0.81295245885849},
#   {'corpus_id': 243, 'score': 0.7987524271011353}],
#  [{'corpus_id': 45, 'score': 0.8723264336585999},
#   {'corpus_id': 268, 'score': 0.8483842015266418},
#   {'corpus_id': 280, 'score': 0.7294826507568359}],
#  [{'corpus_id': 292, 'score': 0.7082032561302185},
#   {'corpus_id': 298, 'score': 0.6905791759490967},
#   {'corpus_id': 111, 'score': 0.6545119285583496}],
#  [{'corpus_id': 78, 'score': 0.3742870092391968},
#   {'corpus_id': 141, 'score': 0.3646027445793152},
#   {'corpus_id': 44, 'score': 0.35163816809654236}],
#  [{'corpus_id': 292, 'score': 0.6524869203567505},
#   {'corpus_id': 298, 'score': 0.6247143149375916},
#   {'corpus_id': 275, 'score': 0.5275797843933105}],
#  [{'corpus_id': 183, 'score': 0.6980566382408142},
#   {'corpus_id': 174, 'score': 0.6293338537216187},
#   {'corpus_id': 295, 'score': 0.6214638352394104}],
#  [{'corpus_id': 52, 'score': 0.7609702944755554},
#   {'corpus_id': 201, 'score': 0.7451358437538147},
#   {'corpus_id': 55, 'score': 0.7346134781837463}],
#  [{'corpus_id': 55, 'score': 0.7691215872764587},
#   {'corpus_id': 174, 'score': 0.7527562975883484},
#   {'corpus_id': 173, 'score': 0.7496500015258789}],
#  [{'corpus_id': 52, 'score': 0.7609702944755554},
#   {'corpus_id': 201, 'score': 0.7451358437538147},
#   {'corpus_id': 55, 'score': 0.7346134781837463}],
#  [{'corpus_id': 52, 'score': 0.7563167214393616},
#   {'corpus_id': 174, 'score': 0.7421888113021851},
#   {'corpus_id': 55, 'score': 0.7375535368919373}],
#  [{'corpus_id': 201, 'score': 0.7487804293632507},
#   {'corpus_id': 52, 'score': 0.7437931895256042},
#   {'corpus_id': 55, 'score': 0.7264731526374817}],
#  [{'corpus_id': 285, 'score': 0.6656902432441711},
#   {'corpus_id': 295, 'score': 0.6640642881393433},
#   {'corpus_id': 68, 'score': 0.6562389731407166}],
#  [{'corpus_id': 55, 'score': 0.767971396446228},
#   {'corpus_id': 169, 'score': 0.7507280111312866},
#   {'corpus_id': 56, 'score': 0.7449991703033447}],
#  [{'corpus_id': 35, 'score': 0.8886157870292664},
#   {'corpus_id': 285, 'score': 0.8469004034996033},
#   {'corpus_id': 95, 'score': 0.8423805236816406}],
#  [{'corpus_id': 48, 'score': 0.9503951668739319},
#   {'corpus_id': 171, 'score': 0.9072425365447998},
#   {'corpus_id': 188, 'score': 0.8516592979431152}],
#  [{'corpus_id': 48, 'score': 0.9944790601730347},
#   {'corpus_id': 171, 'score': 0.8634857535362244},
#   {'corpus_id': 56, 'score': 0.8486496210098267}],
#  [{'corpus_id': 35, 'score': 0.8911539316177368},
#   {'corpus_id': 260, 'score': 0.8592117428779602},
#   {'corpus_id': 285, 'score': 0.8558360934257507}],
#  [{'corpus_id': 50, 'score': 0.9951146245002747},
#   {'corpus_id': 56, 'score': 0.862648606300354},
#   {'corpus_id': 51, 'score': 0.8255971670150757}],
#  [{'corpus_id': 51, 'score': 0.8404369950294495},
#   {'corpus_id': 285, 'score': 0.8226855993270874},
#   {'corpus_id': 95, 'score': 0.802441418170929}],
#  [{'corpus_id': 285, 'score': 0.8486738801002502},
#   {'corpus_id': 51, 'score': 0.8394413590431213},
#   {'corpus_id': 95, 'score': 0.8328421115875244}],
#  [{'corpus_id': 51, 'score': 1.0000003576278687},
#   {'corpus_id': 56, 'score': 0.8756440877914429},
#   {'corpus_id': 200, 'score': 0.8287861943244934}],
#  [{'corpus_id': 285, 'score': 0.8641886711120605},
#   {'corpus_id': 95, 'score': 0.8398258686065674},
#   {'corpus_id': 35, 'score': 0.8202860355377197}],
#  [{'corpus_id': 285, 'score': 0.8683415651321411},
#   {'corpus_id': 95, 'score': 0.8506525158882141},
#   {'corpus_id': 35, 'score': 0.8203250169754028}],
#  [{'corpus_id': 285, 'score': 0.8486738801002502},
#   {'corpus_id': 51, 'score': 0.8394413590431213},
#   {'corpus_id': 95, 'score': 0.8328421115875244}],
#  [{'corpus_id': 52, 'score': 0.994523286819458},
#   {'corpus_id': 55, 'score': 0.8698369860649109},
#   {'corpus_id': 201, 'score': 0.8341794610023499}],
#  [{'corpus_id': 52, 'score': 0.8382551074028015},
#   {'corpus_id': 285, 'score': 0.8307240605354309},
#   {'corpus_id': 95, 'score': 0.8240015506744385}],
#  [{'corpus_id': 52, 'score': 0.8382551074028015},
#   {'corpus_id': 285, 'score': 0.8307240605354309},
#   {'corpus_id': 95, 'score': 0.8240015506744385}],
#  [{'corpus_id': 52, 'score': 0.8382551074028015},
#   {'corpus_id': 285, 'score': 0.8307240605354309},
#   {'corpus_id': 95, 'score': 0.8240015506744385}],
#  [{'corpus_id': 53, 'score': 0.8955825567245483},
#   {'corpus_id': 184, 'score': 0.8446274399757385},
#   {'corpus_id': 52, 'score': 0.765326738357544}],
#  [{'corpus_id': 55, 'score': 0.9089921712875366},
#   {'corpus_id': 52, 'score': 0.7322938442230225},
#   {'corpus_id': 56, 'score': 0.7198203802108765}],
#  [{'corpus_id': 285, 'score': 0.8662573099136353},
#   {'corpus_id': 95, 'score': 0.8441576361656189},
#   {'corpus_id': 260, 'score': 0.8184983730316162}],
#  [{'corpus_id': 56, 'score': 0.9947854280471802},
#   {'corpus_id': 51, 'score': 0.8655497431755066},
#   {'corpus_id': 50, 'score': 0.8471283912658691}],
#  [{'corpus_id': 68, 'score': 0.7932162284851074},
#   {'corpus_id': 55, 'score': 0.770774245262146},
#   {'corpus_id': 93, 'score': 0.7694498300552368}],
#  [{'corpus_id': 68, 'score': 0.7917985320091248},
#   {'corpus_id': 55, 'score': 0.7772931456565857},
#   {'corpus_id': 93, 'score': 0.7750459909439087}],
#  [{'corpus_id': 68, 'score': 0.7456532716751099},
#   {'corpus_id': 285, 'score': 0.696611762046814},
#   {'corpus_id': 260, 'score': 0.6946768164634705}],
#  [{'corpus_id': 57, 'score': 0.7052950263023376},
#   {'corpus_id': 289, 'score': 0.6674932241439819},
#   {'corpus_id': 34, 'score': 0.6288912296295166}],
#  [{'corpus_id': 281, 'score': 0.637118399143219},
#   {'corpus_id': 282, 'score': 0.6173538565635681},
#   {'corpus_id': 287, 'score': 0.5861194133758545}],
#  [{'corpus_id': 282, 'score': 0.7592363357543945},
#   {'corpus_id': 281, 'score': 0.7354315519332886},
#   {'corpus_id': 287, 'score': 0.7311885356903076}],
#  [{'corpus_id': 281, 'score': 0.6434829831123352},
#   {'corpus_id': 282, 'score': 0.6309599876403809},
#   {'corpus_id': 287, 'score': 0.5988390445709229}],
#  [{'corpus_id': 100, 'score': 0.6336548328399658},
#   {'corpus_id': 277, 'score': 0.6124390363693237},
#   {'corpus_id': 92, 'score': 0.6082496643066406}],
#  [{'corpus_id': 281, 'score': 0.6434829831123352},
#   {'corpus_id': 282, 'score': 0.6309599876403809},
#   {'corpus_id': 287, 'score': 0.5988390445709229}],
#  [{'corpus_id': 281, 'score': 0.6240487694740295},
#   {'corpus_id': 287, 'score': 0.6203241348266602},
#   {'corpus_id': 282, 'score': 0.5865676999092102}],
#  [{'corpus_id': 265, 'score': 0.8133803606033325},
#   {'corpus_id': 213, 'score': 0.8057044744491577},
#   {'corpus_id': 186, 'score': 0.784243106842041}],
#  [{'corpus_id': 94, 'score': 0.811349630355835},
#   {'corpus_id': 35, 'score': 0.7991842031478882},
#   {'corpus_id': 199, 'score': 0.7478535175323486}],
#  [{'corpus_id': 213, 'score': 0.8825137615203857},
#   {'corpus_id': 192, 'score': 0.8782981634140015},
#   {'corpus_id': 186, 'score': 0.8416199684143066}],
#  [{'corpus_id': 213, 'score': 0.8186715245246887},
#   {'corpus_id': 265, 'score': 0.8126408457756042},
#   {'corpus_id': 186, 'score': 0.7991799116134644}],
#  [{'corpus_id': 94, 'score': 0.8202739357948303},
#   {'corpus_id': 35, 'score': 0.8096585273742676},
#   {'corpus_id': 199, 'score': 0.762946367263794}],
#  [{'corpus_id': 213, 'score': 0.8360442519187927},
#   {'corpus_id': 265, 'score': 0.8334841132164001},
#   {'corpus_id': 192, 'score': 0.810129702091217}],
#  [{'corpus_id': 213, 'score': 0.8305011987686157},
#   {'corpus_id': 265, 'score': 0.8295437097549438},
#   {'corpus_id': 186, 'score': 0.8028067946434021}],
#  [{'corpus_id': 265, 'score': 0.8185977935791016},
#   {'corpus_id': 213, 'score': 0.8158940672874451},
#   {'corpus_id': 192, 'score': 0.7929096817970276}],
#  [{'corpus_id': 94, 'score': 0.7997090816497803},
#   {'corpus_id': 35, 'score': 0.7942381501197815},
#   {'corpus_id': 199, 'score': 0.7443072199821472}],
#  [{'corpus_id': 265, 'score': 0.8185977935791016},
#   {'corpus_id': 213, 'score': 0.8158940672874451},
#   {'corpus_id': 192, 'score': 0.7929096817970276}],
#  [{'corpus_id': 94, 'score': 0.811349630355835},
#   {'corpus_id': 35, 'score': 0.7991842031478882},
#   {'corpus_id': 199, 'score': 0.7478535175323486}],
#  [{'corpus_id': 213, 'score': 0.8305011987686157},
#   {'corpus_id': 265, 'score': 0.8295437097549438},
#   {'corpus_id': 186, 'score': 0.8028067946434021}],
#  [{'corpus_id': 35, 'score': 0.8661174178123474},
#   {'corpus_id': 285, 'score': 0.7970283627510071},
#   {'corpus_id': 94, 'score': 0.7851856350898743}],
#  [{'corpus_id': 94, 'score': 0.811349630355835},
#   {'corpus_id': 35, 'score': 0.7991842031478882},
#   {'corpus_id': 199, 'score': 0.7478535175323486}],
#  [{'corpus_id': 265, 'score': 0.8185977935791016},
#   {'corpus_id': 213, 'score': 0.8158940672874451},
#   {'corpus_id': 192, 'score': 0.7929096817970276}],
#  [{'corpus_id': 213, 'score': 0.8305011987686157},
#   {'corpus_id': 265, 'score': 0.8295437097549438},
#   {'corpus_id': 186, 'score': 0.8028067946434021}],
#  [{'corpus_id': 39, 'score': 0.8551087379455566},
#   {'corpus_id': 124, 'score': 0.832036554813385},
#   {'corpus_id': 111, 'score': 0.831253707408905}],
#  [{'corpus_id': 124, 'score': 0.8859899640083313},
#   {'corpus_id': 39, 'score': 0.8276124596595764},
#   {'corpus_id': 88, 'score': 0.806183934211731}],
#  [{'corpus_id': 213, 'score': 0.9193639755249023},
#   {'corpus_id': 192, 'score': 0.9001699686050415},
#   {'corpus_id': 186, 'score': 0.8689782619476318}],
#  [{'corpus_id': 87, 'score': 0.6308212280273438},
#   {'corpus_id': 20, 'score': 0.6179335117340088},
#   {'corpus_id': 66, 'score': 0.6173998713493347}],
#  [{'corpus_id': 60, 'score': 0.7171419858932495},
#   {'corpus_id': 61, 'score': 0.5500199794769287},
#   {'corpus_id': 71, 'score': 0.5103275775909424}],
#  [{'corpus_id': 61, 'score': 0.9448270201683044},
#   {'corpus_id': 60, 'score': 0.8236873149871826},
#   {'corpus_id': 36, 'score': 0.7525957226753235}],
#  [{'corpus_id': 61, 'score': 0.7014405131340027},
#   {'corpus_id': 105, 'score': 0.4840660095214844},
#   {'corpus_id': 60, 'score': 0.44931846857070923}],
#  [{'corpus_id': 61, 'score': 0.9448270201683044},
#   {'corpus_id': 60, 'score': 0.8236873149871826},
#   {'corpus_id': 36, 'score': 0.7525957226753235}],
#  [{'corpus_id': 61, 'score': 0.9448270201683044},
#   {'corpus_id': 60, 'score': 0.8236873149871826},
#   {'corpus_id': 36, 'score': 0.7525957226753235}],
#  [{'corpus_id': 62, 'score': 0.9252488613128662},
#   {'corpus_id': 221, 'score': 0.7179970741271973},
#   {'corpus_id': 295, 'score': 0.6803045868873596}],
#  [{'corpus_id': 62, 'score': 0.9252488613128662},
#   {'corpus_id': 221, 'score': 0.7179970741271973},
#   {'corpus_id': 295, 'score': 0.6803045868873596}],
#  [{'corpus_id': 62, 'score': 0.9473743438720703},
#   {'corpus_id': 221, 'score': 0.7156416773796082},
#   {'corpus_id': 295, 'score': 0.685945451259613}],
#  [{'corpus_id': 63, 'score': 0.7799378633499146},
#   {'corpus_id': 174, 'score': 0.740964949131012},
#   {'corpus_id': 178, 'score': 0.737754225730896}],
#  [{'corpus_id': 230, 'score': 0.8623834252357483},
#   {'corpus_id': 184, 'score': 0.7892964482307434},
#   {'corpus_id': 53, 'score': 0.7461217641830444}],
#  [{'corpus_id': 93, 'score': 0.8500464558601379},
#   {'corpus_id': 104, 'score': 0.8222545385360718},
#   {'corpus_id': 181, 'score': 0.8107365369796753}],
#  [{'corpus_id': 290, 'score': 0.899830162525177},
#   {'corpus_id': 95, 'score': 0.823805570602417},
#   {'corpus_id': 94, 'score': 0.7651364207267761}],
#  [{'corpus_id': 67, 'score': 0.8356592655181885},
#   {'corpus_id': 94, 'score': 0.8066366910934448},
#   {'corpus_id': 95, 'score': 0.7855480313301086}],
#  [{'corpus_id': 180, 'score': 0.8925157189369202},
#   {'corpus_id': 68, 'score': 0.7730125784873962},
#   {'corpus_id': 176, 'score': 0.755413830280304}],
#  [{'corpus_id': 180, 'score': 0.892400860786438},
#   {'corpus_id': 176, 'score': 0.7629702091217041},
#   {'corpus_id': 68, 'score': 0.7566270232200623}],
#  [{'corpus_id': 68, 'score': 0.9002713561058044},
#   {'corpus_id': 285, 'score': 0.8313701748847961},
#   {'corpus_id': 93, 'score': 0.8289384841918945}],
#  [{'corpus_id': 68, 'score': 0.9803990721702576},
#   {'corpus_id': 285, 'score': 0.8552216291427612},
#   {'corpus_id': 260, 'score': 0.7884385585784912}],
#  [{'corpus_id': 69, 'score': 0.8647852540016174},
#   {'corpus_id': 217, 'score': 0.7774073481559753},
#   {'corpus_id': 219, 'score': 0.7092612981796265}],
#  [{'corpus_id': 70, 'score': 0.7828018665313721},
#   {'corpus_id': 94, 'score': 0.7251443266868591},
#   {'corpus_id': 95, 'score': 0.6876356601715088}],
#  [{'corpus_id': 92, 'score': 0.7544142007827759},
#   {'corpus_id': 285, 'score': 0.7512662410736084},
#   {'corpus_id': 290, 'score': 0.7487466335296631}],
#  [{'corpus_id': 285, 'score': 0.7518739104270935},
#   {'corpus_id': 290, 'score': 0.7295231223106384},
#   {'corpus_id': 35, 'score': 0.729133665561676}],
#  [{'corpus_id': 92, 'score': 0.8147779107093811},
#   {'corpus_id': 290, 'score': 0.7533922791481018},
#   {'corpus_id': 102, 'score': 0.733874499797821}],
#  [{'corpus_id': 71, 'score': 0.7960608005523682},
#   {'corpus_id': 92, 'score': 0.6888666749000549},
#   {'corpus_id': 9, 'score': 0.6466807126998901}],
#  [{'corpus_id': 92, 'score': 0.9357694387435913},
#   {'corpus_id': 9, 'score': 0.8525846600532532},
#   {'corpus_id': 102, 'score': 0.8299157023429871}],
#  [{'corpus_id': 92, 'score': 0.8168538212776184},
#   {'corpus_id': 290, 'score': 0.760836660861969},
#   {'corpus_id': 102, 'score': 0.7426766753196716}],
#  [{'corpus_id': 55, 'score': 0.717627227306366},
#   {'corpus_id': 50, 'score': 0.6975088715553284},
#   {'corpus_id': 52, 'score': 0.6889216899871826}],
#  [{'corpus_id': 95, 'score': 0.8505638241767883},
#   {'corpus_id': 290, 'score': 0.801735520362854},
#   {'corpus_id': 285, 'score': 0.7863613963127136}],
#  [{'corpus_id': 285, 'score': 0.8200790286064148},
#   {'corpus_id': 95, 'score': 0.7918626070022583},
#   {'corpus_id': 35, 'score': 0.7710832357406616}],
#  [{'corpus_id': 74, 'score': 0.7908889055252075},
#   {'corpus_id': 201, 'score': 0.7539676427841187},
#   {'corpus_id': 52, 'score': 0.7427693009376526}],
#  [{'corpus_id': 75, 'score': 0.7109901309013367},
#   {'corpus_id': 8, 'score': 0.5961458683013916},
#   {'corpus_id': 58, 'score': 0.5707406401634216}],
#  [{'corpus_id': 135, 'score': 0.7353307604789734},
#   {'corpus_id': 104, 'score': 0.5861475467681885},
#   {'corpus_id': 34, 'score': 0.5840296745300293}],
#  [{'corpus_id': 193, 'score': 0.8779075741767883},
#   {'corpus_id': 204, 'score': 0.8635163903236389},
#   {'corpus_id': 210, 'score': 0.8541654944419861}],
#  [{'corpus_id': 175, 'score': 0.7345247268676758},
#   {'corpus_id': 77, 'score': 0.7204714417457581},
#   {'corpus_id': 208, 'score': 0.7011261582374573}],
#  [{'corpus_id': 175, 'score': 0.7327592968940735},
#   {'corpus_id': 77, 'score': 0.7108866572380066},
#   {'corpus_id': 169, 'score': 0.7024292349815369}],
#  [{'corpus_id': 175, 'score': 0.7255554795265198},
#   {'corpus_id': 67, 'score': 0.6986121535301208},
#   {'corpus_id': 208, 'score': 0.6975056529045105}],
#  [{'corpus_id': 175, 'score': 0.7327592968940735},
#   {'corpus_id': 77, 'score': 0.7108866572380066},
#   {'corpus_id': 169, 'score': 0.7024292349815369}],
#  [{'corpus_id': 92, 'score': 0.7443029284477234},
#   {'corpus_id': 290, 'score': 0.7223616242408752},
#   {'corpus_id': 35, 'score': 0.7173746824264526}],
#  [{'corpus_id': 285, 'score': 0.7509161829948425},
#   {'corpus_id': 35, 'score': 0.7447264790534973},
#   {'corpus_id': 92, 'score': 0.741461455821991}],
#  [{'corpus_id': 92, 'score': 0.7926914095878601},
#   {'corpus_id': 10, 'score': 0.7391225099563599},
#   {'corpus_id': 102, 'score': 0.7210547924041748}],
#  [{'corpus_id': 92, 'score': 0.7443029284477234},
#   {'corpus_id': 290, 'score': 0.7223616242408752},
#   {'corpus_id': 35, 'score': 0.7173746824264526}],
#  [{'corpus_id': 92, 'score': 0.8945502638816833},
#   {'corpus_id': 9, 'score': 0.8144872188568115},
#   {'corpus_id': 102, 'score': 0.7986653447151184}],
#  [{'corpus_id': 92, 'score': 0.8033750653266907},
#   {'corpus_id': 10, 'score': 0.7454052567481995},
#   {'corpus_id': 290, 'score': 0.7360113263130188}],
#  [{'corpus_id': 290, 'score': 0.7456095814704895},
#   {'corpus_id': 282, 'score': 0.7092157006263733},
#   {'corpus_id': 196, 'score': 0.7054515480995178}],
#  [{'corpus_id': 78, 'score': 0.8038285374641418},
#   {'corpus_id': 96, 'score': 0.5753112435340881},
#   {'corpus_id': 92, 'score': 0.5690929293632507}],
#  [{'corpus_id': 285, 'score': 0.7237605452537537},
#   {'corpus_id': 283, 'score': 0.7151581645011902},
#   {'corpus_id': 290, 'score': 0.6904116868972778}],
#  [{'corpus_id': 150, 'score': 0.8568991422653198},
#   {'corpus_id': 136, 'score': 0.7840738892555237},
#   {'corpus_id': 79, 'score': 0.7662721276283264}],
#  [{'corpus_id': 150, 'score': 0.8568991422653198},
#   {'corpus_id': 136, 'score': 0.7840738892555237},
#   {'corpus_id': 79, 'score': 0.7662721276283264}],
#  [{'corpus_id': 81, 'score': 0.7611377835273743},
#   {'corpus_id': 260, 'score': 0.7475042939186096},
#   {'corpus_id': 68, 'score': 0.7391270995140076}],
#  [{'corpus_id': 68, 'score': 0.7174558043479919},
#   {'corpus_id': 260, 'score': 0.7057936787605286},
#   {'corpus_id': 285, 'score': 0.6910001635551453}],
#  [{'corpus_id': 260, 'score': 0.773178219795227},
#   {'corpus_id': 68, 'score': 0.7664656043052673},
#   {'corpus_id': 285, 'score': 0.7407958507537842}],
#  [{'corpus_id': 81, 'score': 0.9941509962081909},
#   {'corpus_id': 82, 'score': 0.8180224895477295},
#   {'corpus_id': 176, 'score': 0.6872978806495667}],
#  [{'corpus_id': 260, 'score': 0.773178219795227},
#   {'corpus_id': 68, 'score': 0.7664656043052673},
#   {'corpus_id': 285, 'score': 0.7407958507537842}],
#  [{'corpus_id': 68, 'score': 0.7535459399223328},
#   {'corpus_id': 260, 'score': 0.7484179139137268},
#   {'corpus_id': 285, 'score': 0.723561704158783}],
#  [{'corpus_id': 81, 'score': 0.7611377835273743},
#   {'corpus_id': 260, 'score': 0.7475042939186096},
#   {'corpus_id': 68, 'score': 0.7391270995140076}],
#  [{'corpus_id': 82, 'score': 0.8686116337776184},
#   {'corpus_id': 81, 'score': 0.6700382828712463},
#   {'corpus_id': 70, 'score': 0.5550525188446045}],
#  [{'corpus_id': 82, 'score': 0.7629571557044983},
#   {'corpus_id': 81, 'score': 0.6859810948371887},
#   {'corpus_id': 254, 'score': 0.6296701431274414}],
#  [{'corpus_id': 82, 'score': 0.87808758020401},
#   {'corpus_id': 81, 'score': 0.6923368573188782},
#   {'corpus_id': 70, 'score': 0.5907259583473206}],
#  [{'corpus_id': 130, 'score': 0.623472273349762},
#   {'corpus_id': 82, 'score': 0.6065178513526917},
#   {'corpus_id': 39, 'score': 0.6042639017105103}],
#  [{'corpus_id': 83, 'score': 0.8115182518959045},
#   {'corpus_id': 168, 'score': 0.6800343990325928},
#   {'corpus_id': 231, 'score': 0.6344819664955139}],
#  [{'corpus_id': 93, 'score': 0.7507377862930298},
#   {'corpus_id': 168, 'score': 0.7489687204360962},
#   {'corpus_id': 285, 'score': 0.7353511452674866}],
#  [{'corpus_id': 93, 'score': 0.7464060187339783},
#   {'corpus_id': 260, 'score': 0.729736864566803},
#   {'corpus_id': 91, 'score': 0.7290111780166626}],
#  [{'corpus_id': 83, 'score': 0.9909377694129944},
#   {'corpus_id': 168, 'score': 0.7990103363990784},
#   {'corpus_id': 231, 'score': 0.6598812341690063}],
#  [{'corpus_id': 195, 'score': 0.8293030858039856},
#   {'corpus_id': 138, 'score': 0.8268517255783081},
#   {'corpus_id': 291, 'score': 0.7841751575469971}],
#  [{'corpus_id': 138, 'score': 0.8448282480239868},
#   {'corpus_id': 104, 'score': 0.8060588836669922},
#   {'corpus_id': 195, 'score': 0.8058010935783386}],
#  [{'corpus_id': 279, 'score': 0.8363950848579407},
#   {'corpus_id': 275, 'score': 0.8111385107040405},
#   {'corpus_id': 85, 'score': 0.7608794569969177}],
#  [{'corpus_id': 279, 'score': 0.8286600708961487},
#   {'corpus_id': 275, 'score': 0.8012781143188477},
#   {'corpus_id': 85, 'score': 0.7741087675094604}],
#  [{'corpus_id': 292, 'score': 0.6654199957847595},
#   {'corpus_id': 298, 'score': 0.6573398113250732},
#   {'corpus_id': 282, 'score': 0.5378432273864746}],
#  [{'corpus_id': 279, 'score': 0.8286600708961487},
#   {'corpus_id': 275, 'score': 0.8012781143188477},
#   {'corpus_id': 85, 'score': 0.7741087675094604}],
#  [{'corpus_id': 292, 'score': 0.6654199957847595},
#   {'corpus_id': 298, 'score': 0.6573398113250732},
#   {'corpus_id': 282, 'score': 0.5378432273864746}],
#  [{'corpus_id': 86, 'score': 0.524856686592102},
#   {'corpus_id': 85, 'score': 0.4506077468395233},
#   {'corpus_id': 285, 'score': 0.3930186331272125}],
#  [{'corpus_id': 180, 'score': 0.9094429016113281},
#   {'corpus_id': 285, 'score': 0.8114739060401917},
#   {'corpus_id': 86, 'score': 0.7975886464118958}],
#  [{'corpus_id': 285, 'score': 0.9293340444564819},
#   {'corpus_id': 95, 'score': 0.8286858201026917},
#   {'corpus_id': 94, 'score': 0.8183341026306152}],
#  [{'corpus_id': 285, 'score': 0.903670608997345},
#   {'corpus_id': 95, 'score': 0.8251320719718933},
#   {'corpus_id': 68, 'score': 0.7999939918518066}],
#  [{'corpus_id': 292, 'score': 0.6654199957847595},
#   {'corpus_id': 298, 'score': 0.6573398113250732},
#   {'corpus_id': 282, 'score': 0.5378432273864746}],
#  [{'corpus_id': 285, 'score': 0.9898385405540466},
#   {'corpus_id': 68, 'score': 0.8457090258598328},
#   {'corpus_id': 260, 'score': 0.8115371465682983}],
#  [{'corpus_id': 285, 'score': 0.9293340444564819},
#   {'corpus_id': 95, 'score': 0.8286858201026917},
#   {'corpus_id': 94, 'score': 0.8183341026306152}],
#  [{'corpus_id': 285, 'score': 0.8834011554718018},
#   {'corpus_id': 95, 'score': 0.8066327571868896},
#   {'corpus_id': 68, 'score': 0.7863291501998901}],
#  [{'corpus_id': 285, 'score': 0.9293340444564819},
#   {'corpus_id': 95, 'score': 0.8286858201026917},
#   {'corpus_id': 94, 'score': 0.8183341026306152}],
#  [{'corpus_id': 285, 'score': 0.9899747371673584},
#   {'corpus_id': 68, 'score': 0.8435461521148682},
#   {'corpus_id': 260, 'score': 0.8198789954185486}],
#  [{'corpus_id': 220, 'score': 0.8098798990249634},
#   {'corpus_id': 176, 'score': 0.8030843138694763},
#   {'corpus_id': 204, 'score': 0.7952727675437927}],
#  [{'corpus_id': 87, 'score': 0.7806713581085205},
#   {'corpus_id': 289, 'score': 0.7352288961410522},
#   {'corpus_id': 290, 'score': 0.7233090996742249}],
#  [{'corpus_id': 87, 'score': 0.7806713581085205},
#   {'corpus_id': 289, 'score': 0.7352288961410522},
#   {'corpus_id': 290, 'score': 0.7233090996742249}],
#  [{'corpus_id': 220, 'score': 0.9034650921821594},
#   {'corpus_id': 204, 'score': 0.892737865447998},
#   {'corpus_id': 209, 'score': 0.8590733408927917}],
#  [{'corpus_id': 68, 'score': 0.7819058895111084},
#   {'corpus_id': 285, 'score': 0.7495805025100708},
#   {'corpus_id': 260, 'score': 0.7440118789672852}],
#  [{'corpus_id': 220, 'score': 0.8826366662979126},
#   {'corpus_id': 204, 'score': 0.8669627904891968},
#   {'corpus_id': 209, 'score': 0.8342490792274475}],
#  [{'corpus_id': 91, 'score': 0.8406839966773987},
#   {'corpus_id': 220, 'score': 0.8234550952911377},
#   {'corpus_id': 204, 'score': 0.818134605884552}],
#  [{'corpus_id': 220, 'score': 0.8826366662979126},
#   {'corpus_id': 204, 'score': 0.8669627904891968},
#   {'corpus_id': 209, 'score': 0.8342490792274475}],
#  [{'corpus_id': 220, 'score': 0.8342667818069458},
#   {'corpus_id': 91, 'score': 0.8160685300827026},
#   {'corpus_id': 204, 'score': 0.8155086040496826}],
#  [{'corpus_id': 220, 'score': 0.8342667818069458},
#   {'corpus_id': 91, 'score': 0.8160685300827026},
#   {'corpus_id': 204, 'score': 0.8155086040496826}],
#  [{'corpus_id': 220, 'score': 0.8103848695755005},
#   {'corpus_id': 68, 'score': 0.8103553056716919},
#   {'corpus_id': 91, 'score': 0.8015506863594055}],
#  [{'corpus_id': 220, 'score': 0.8103848695755005},
#   {'corpus_id': 68, 'score': 0.8103553056716919},
#   {'corpus_id': 91, 'score': 0.8015506863594055}],
#  [{'corpus_id': 220, 'score': 0.8342667818069458},
#   {'corpus_id': 91, 'score': 0.8160685300827026},
#   {'corpus_id': 204, 'score': 0.8155086040496826}],
#  [{'corpus_id': 91, 'score': 0.8305485248565674},
#   {'corpus_id': 104, 'score': 0.7985786199569702},
#   {'corpus_id': 211, 'score': 0.7936853766441345}],
#  [{'corpus_id': 220, 'score': 0.807831346988678},
#   {'corpus_id': 68, 'score': 0.8057501316070557},
#   {'corpus_id': 204, 'score': 0.8032702803611755}],
#  [{'corpus_id': 68, 'score': 0.8249196410179138},
#   {'corpus_id': 35, 'score': 0.82090824842453},
#   {'corpus_id': 91, 'score': 0.8192628622055054}],
#  [{'corpus_id': 220, 'score': 0.8826366662979126},
#   {'corpus_id': 204, 'score': 0.8669627904891968},
#   {'corpus_id': 209, 'score': 0.8342490792274475}],
#  [{'corpus_id': 92, 'score': 0.6411923170089722},
#   {'corpus_id': 19, 'score': 0.5986619591712952},
#   {'corpus_id': 11, 'score': 0.5944355130195618}],
#  [{'corpus_id': 89, 'score': 0.5963010191917419},
#   {'corpus_id': 96, 'score': 0.5366345643997192},
#   {'corpus_id': 156, 'score': 0.5092841982841492}],
#  [{'corpus_id': 287, 'score': 0.6781978011131287},
#   {'corpus_id': 282, 'score': 0.6759600043296814},
#   {'corpus_id': 276, 'score': 0.6638092398643494}],
#  [{'corpus_id': 244, 'score': 0.643912136554718},
#   {'corpus_id': 240, 'score': 0.6170700192451477},
#   {'corpus_id': 157, 'score': 0.6129786968231201}],
#  [{'corpus_id': 244, 'score': 0.643912136554718},
#   {'corpus_id': 240, 'score': 0.6170700192451477},
#   {'corpus_id': 157, 'score': 0.6129786968231201}],
#  [{'corpus_id': 90, 'score': 0.5206338763237},
#   {'corpus_id': 101, 'score': 0.4417770206928253},
#   {'corpus_id': 132, 'score': 0.43718090653419495}],
#  [{'corpus_id': 90, 'score': 1.000000238418579},
#   {'corpus_id': 25, 'score': 0.8932127356529236},
#   {'corpus_id': 251, 'score': 0.8373042941093445}],
#  [{'corpus_id': 91, 'score': 0.9381124377250671},
#   {'corpus_id': 93, 'score': 0.800720751285553},
#   {'corpus_id': 182, 'score': 0.7912812232971191}],
#  [{'corpus_id': 91, 'score': 0.9914012551307678},
#   {'corpus_id': 182, 'score': 0.860912024974823},
#   {'corpus_id': 93, 'score': 0.853644847869873}],
#  [{'corpus_id': 92, 'score': 0.9683745503425598},
#   {'corpus_id': 9, 'score': 0.862877607345581},
#   {'corpus_id': 102, 'score': 0.8536471724510193}],
#  [{'corpus_id': 92, 'score': 0.83953458070755},
#   {'corpus_id': 10, 'score': 0.775955855846405},
#   {'corpus_id': 290, 'score': 0.7751920819282532}],
#  [{'corpus_id': 283, 'score': 0.7550277709960938},
#   {'corpus_id': 285, 'score': 0.7381202578544617},
#   {'corpus_id': 290, 'score': 0.7337936162948608}],
#  [{'corpus_id': 285, 'score': 0.7802758812904358},
#   {'corpus_id': 35, 'score': 0.7681521773338318},
#   {'corpus_id': 290, 'score': 0.7644763588905334}],
#  [{'corpus_id': 35, 'score': 0.7772143483161926},
# ...
#   {'corpus_id': 244, 'score': 0.8952529430389404},
#   {'corpus_id': 273, 'score': 0.8590554594993591}],
#  [{'corpus_id': 223, 'score': 0.9391234517097473},
#   {'corpus_id': 244, 'score': 0.9005327820777893},
#   {'corpus_id': 273, 'score': 0.861199140548706}],
#  [{'corpus_id': 223, 'score': 0.9391234517097473},
#   {'corpus_id': 244, 'score': 0.9005327820777893},
#   {'corpus_id': 273, 'score': 0.861199140548706}],
#  [{'corpus_id': 204, 'score': 0.926970899105072},
#   {'corpus_id': 220, 'score': 0.8464552164077759},
#   {'corpus_id': 212, 'score': 0.8080430626869202}],
#  [{'corpus_id': 223, 'score': 0.8952600955963135},
#   {'corpus_id': 273, 'score': 0.8809757828712463},
#   {'corpus_id': 244, 'score': 0.852807879447937}],
#  [{'corpus_id': 204, 'score': 0.8899827599525452},
#   {'corpus_id': 245, 'score': 0.8863239288330078},
#   {'corpus_id': 244, 'score': 0.8692895770072937}],
#  [{'corpus_id': 290, 'score': 0.7459719181060791},
#   {'corpus_id': 283, 'score': 0.7315267324447632},
#   {'corpus_id': 285, 'score': 0.6959602236747742}],
#  [{'corpus_id': 285, 'score': 0.7208248972892761},
#   {'corpus_id': 95, 'score': 0.7144100069999695},
#   {'corpus_id': 35, 'score': 0.709185779094696}],
#  [{'corpus_id': 12, 'score': 0.5133800506591797},
#   {'corpus_id': 153, 'score': 0.473577082157135},
#   {'corpus_id': 134, 'score': 0.44579413533210754}],
#  [{'corpus_id': 290, 'score': 0.8054136037826538},
#   {'corpus_id': 283, 'score': 0.7272022366523743},
#   {'corpus_id': 95, 'score': 0.7179010510444641}],
#  [{'corpus_id': 290, 'score': 0.8021682500839233},
#   {'corpus_id': 95, 'score': 0.7290478944778442},
#   {'corpus_id': 285, 'score': 0.7182679176330566}],
#  [{'corpus_id': 285, 'score': 0.7208248972892761},
#   {'corpus_id': 95, 'score': 0.7144100069999695},
#   {'corpus_id': 35, 'score': 0.709185779094696}],
#  [{'corpus_id': 247, 'score': 0.8124843835830688},
#   {'corpus_id': 248, 'score': 0.8087103366851807},
#   {'corpus_id': 241, 'score': 0.79297935962677}],
#  [{'corpus_id': 290, 'score': 0.8177531361579895},
#   {'corpus_id': 95, 'score': 0.8135347366333008},
#   {'corpus_id': 247, 'score': 0.8092749714851379}],
#  [{'corpus_id': 290, 'score': 0.8177531361579895},
#   {'corpus_id': 95, 'score': 0.8135347366333008},
#   {'corpus_id': 247, 'score': 0.8092749714851379}],
#  [{'corpus_id': 290, 'score': 0.7973662614822388},
#   {'corpus_id': 95, 'score': 0.763505756855011},
#   {'corpus_id': 247, 'score': 0.7102766036987305}],
#  [{'corpus_id': 248, 'score': 0.7635976076126099},
#   {'corpus_id': 247, 'score': 0.754932701587677},
#   {'corpus_id': 261, 'score': 0.748050332069397}],
#  [{'corpus_id': 290, 'score': 0.8082771301269531},
#   {'corpus_id': 95, 'score': 0.777900755405426},
#   {'corpus_id': 247, 'score': 0.7124266624450684}],
#  [{'corpus_id': 290, 'score': 0.8082771301269531},
#   {'corpus_id': 95, 'score': 0.777900755405426},
#   {'corpus_id': 247, 'score': 0.7124266624450684}],
#  [{'corpus_id': 290, 'score': 0.7944554090499878},
#   {'corpus_id': 247, 'score': 0.7814133763313293},
#   {'corpus_id': 95, 'score': 0.777417778968811}],
#  [{'corpus_id': 248, 'score': 0.8334749937057495},
#   {'corpus_id': 240, 'score': 0.7852727174758911},
#   {'corpus_id': 241, 'score': 0.7849839329719543}],
#  [{'corpus_id': 290, 'score': 0.8901571035385132},
#   {'corpus_id': 248, 'score': 0.8036370277404785},
#   {'corpus_id': 95, 'score': 0.7886829972267151}],
#  [{'corpus_id': 290, 'score': 0.8680109977722168},
#   {'corpus_id': 248, 'score': 0.7810561060905457},
#   {'corpus_id': 95, 'score': 0.7633611559867859}],
#  [{'corpus_id': 290, 'score': 0.8705645799636841},
#   {'corpus_id': 248, 'score': 0.7862969636917114},
#   {'corpus_id': 95, 'score': 0.7723190188407898}],
#  [{'corpus_id': 290, 'score': 0.8207870125770569},
#   {'corpus_id': 95, 'score': 0.7465929388999939},
#   {'corpus_id': 248, 'score': 0.7175774574279785}],
#  [{'corpus_id': 124, 'score': 0.7683767080307007},
#   {'corpus_id': 143, 'score': 0.7584152221679688},
#   {'corpus_id': 39, 'score': 0.7564244866371155}],
#  [{'corpus_id': 290, 'score': 0.8505849242210388},
#   {'corpus_id': 95, 'score': 0.7834987044334412},
#   {'corpus_id': 248, 'score': 0.7451067566871643}],
#  [{'corpus_id': 290, 'score': 0.8680109977722168},
#   {'corpus_id': 248, 'score': 0.7810561060905457},
#   {'corpus_id': 95, 'score': 0.7633611559867859}],
#  [{'corpus_id': 265, 'score': 0.6694255471229553},
#   {'corpus_id': 283, 'score': 0.6225785613059998},
#   {'corpus_id': 249, 'score': 0.6108357310295105}],
#  [{'corpus_id': 290, 'score': 0.7856301665306091},
#   {'corpus_id': 249, 'score': 0.785485565662384},
#   {'corpus_id': 95, 'score': 0.7237663269042969}],
#  [{'corpus_id': 249, 'score': 0.8055955767631531},
#   {'corpus_id': 248, 'score': 0.7977365851402283},
#   {'corpus_id': 290, 'score': 0.78887939453125}],
#  [{'corpus_id': 249, 'score': 0.8459163904190063},
#   {'corpus_id': 246, 'score': 0.7291461825370789},
#   {'corpus_id': 248, 'score': 0.7151870727539062}],
#  [{'corpus_id': 283, 'score': 0.7132598757743835},
#   {'corpus_id': 290, 'score': 0.6441594362258911},
#   {'corpus_id': 95, 'score': 0.5792506337165833}],
#  [{'corpus_id': 283, 'score': 0.6559886336326599},
#   {'corpus_id': 290, 'score': 0.6136937737464905},
#   {'corpus_id': 289, 'score': 0.5832905173301697}],
#  [{'corpus_id': 283, 'score': 0.7132598757743835},
#   {'corpus_id': 290, 'score': 0.6441594362258911},
#   {'corpus_id': 95, 'score': 0.5792506337165833}],
#  [{'corpus_id': 249, 'score': 0.9651246666908264},
#   {'corpus_id': 246, 'score': 0.9072481989860535},
#   {'corpus_id': 261, 'score': 0.8782345652580261}],
#  [{'corpus_id': 249, 'score': 0.6269567608833313},
#   {'corpus_id': 177, 'score': 0.5857114195823669},
#   {'corpus_id': 141, 'score': 0.5572293996810913}],
#  [{'corpus_id': 95, 'score': 0.7894647717475891},
#   {'corpus_id': 91, 'score': 0.7877917289733887},
#   {'corpus_id': 94, 'score': 0.746631920337677}],
#  [{'corpus_id': 282, 'score': 0.7181923389434814},
#   {'corpus_id': 223, 'score': 0.6344603300094604},
#   {'corpus_id': 290, 'score': 0.6182617545127869}],
#  [{'corpus_id': 282, 'score': 0.7926510572433472},
#   {'corpus_id': 287, 'score': 0.7182365655899048},
#   {'corpus_id': 281, 'score': 0.7046298384666443}],
#  [{'corpus_id': 229, 'score': 0.6301233768463135},
#   {'corpus_id': 282, 'score': 0.6179239153862},
#   {'corpus_id': 100, 'score': 0.6157862544059753}],
#  [{'corpus_id': 117, 'score': 0.6839538216590881},
#   {'corpus_id': 66, 'score': 0.665258526802063},
#   {'corpus_id': 88, 'score': 0.6463518738746643}],
#  [{'corpus_id': 285, 'score': 0.8323375582695007},
#   {'corpus_id': 93, 'score': 0.8147776126861572},
#   {'corpus_id': 180, 'score': 0.8129459619522095}],
#  [{'corpus_id': 68, 'score': 0.8200609683990479},
#   {'corpus_id': 93, 'score': 0.8190524578094482},
#   {'corpus_id': 285, 'score': 0.8127157688140869}],
#  [{'corpus_id': 253, 'score': 0.7747194766998291},
#   {'corpus_id': 182, 'score': 0.7471586465835571},
#   {'corpus_id': 140, 'score': 0.7138089537620544}],
#  [{'corpus_id': 254, 'score': 0.9580478668212891},
#   {'corpus_id': 70, 'score': 0.6553788185119629},
#   {'corpus_id': 96, 'score': 0.6476734280586243}],
#  [{'corpus_id': 260, 'score': 0.813869833946228},
#   {'corpus_id': 285, 'score': 0.8069602847099304},
#   {'corpus_id': 68, 'score': 0.802067220211029}],
#  [{'corpus_id': 181, 'score': 0.8483549356460571},
#   {'corpus_id': 93, 'score': 0.8348868489265442},
#   {'corpus_id': 104, 'score': 0.7975723147392273}],
#  [{'corpus_id': 285, 'score': 0.8682654500007629},
#   {'corpus_id': 180, 'score': 0.8414334058761597},
#   {'corpus_id': 95, 'score': 0.8301578164100647}],
#  [{'corpus_id': 285, 'score': 0.8682654500007629},
#   {'corpus_id': 180, 'score': 0.8414334058761597},
#   {'corpus_id': 95, 'score': 0.8301578164100647}],
#  [{'corpus_id': 285, 'score': 0.8861067891120911},
#   {'corpus_id': 68, 'score': 0.8311762809753418},
#   {'corpus_id': 35, 'score': 0.8198010325431824}],
#  [{'corpus_id': 180, 'score': 0.9361761212348938},
#   {'corpus_id': 256, 'score': 0.8322464823722839},
#   {'corpus_id': 51, 'score': 0.827179491519928}],
#  [{'corpus_id': 180, 'score': 0.9361761212348938},
#   {'corpus_id': 256, 'score': 0.8322464823722839},
#   {'corpus_id': 51, 'score': 0.827179491519928}],
#  [{'corpus_id': 285, 'score': 0.9277094006538391},
#   {'corpus_id': 35, 'score': 0.8580147624015808},
#   {'corpus_id': 68, 'score': 0.8301677703857422}],
#  [{'corpus_id': 260, 'score': 0.7743131518363953},
#   {'corpus_id': 93, 'score': 0.7589619755744934},
#   {'corpus_id': 91, 'score': 0.7337174415588379}],
#  [{'corpus_id': 260, 'score': 0.7617545127868652},
#   {'corpus_id': 93, 'score': 0.7264290452003479},
#   {'corpus_id': 68, 'score': 0.7067926526069641}],
#  [{'corpus_id': 168, 'score': 0.9369441270828247},
#   {'corpus_id': 83, 'score': 0.7730724811553955},
#   {'corpus_id': 257, 'score': 0.7725956439971924}],
#  [{'corpus_id': 207, 'score': 0.8118172287940979},
#   {'corpus_id': 206, 'score': 0.795961856842041},
#   {'corpus_id': 53, 'score': 0.7612929344177246}],
#  [{'corpus_id': 258, 'score': 0.7767324447631836},
#   {'corpus_id': 160, 'score': 0.6857333183288574},
#   {'corpus_id': 281, 'score': 0.6611833572387695}],
#  [{'corpus_id': 260, 'score': 0.7427722811698914},
#   {'corpus_id': 35, 'score': 0.7298247814178467},
#   {'corpus_id': 93, 'score': 0.7291308045387268}],
#  [{'corpus_id': 104, 'score': 0.7413442134857178},
#   {'corpus_id': 93, 'score': 0.7297378182411194},
#   {'corpus_id': 91, 'score': 0.6893355846405029}],
#  [{'corpus_id': 168, 'score': 0.7422353029251099},
#   {'corpus_id': 208, 'score': 0.6411977410316467},
#   {'corpus_id': 51, 'score': 0.6296482086181641}],
#  [{'corpus_id': 93, 'score': 0.7683003544807434},
#   {'corpus_id': 260, 'score': 0.7405316233634949},
#   {'corpus_id': 259, 'score': 0.7209088802337646}],
#  [{'corpus_id': 168, 'score': 0.7422353029251099},
#   {'corpus_id': 208, 'score': 0.6411977410316467},
#   {'corpus_id': 51, 'score': 0.6296482086181641}],
#  [{'corpus_id': 259, 'score': 0.7916380167007446},
#   {'corpus_id': 93, 'score': 0.7611033320426941},
#   {'corpus_id': 233, 'score': 0.7521443963050842}],
#  [{'corpus_id': 265, 'score': 0.9371799230575562},
#   {'corpus_id': 95, 'score': 0.68536776304245},
#   {'corpus_id': 35, 'score': 0.6747523546218872}],
#  [{'corpus_id': 265, 'score': 0.9371799230575562},
#   {'corpus_id': 95, 'score': 0.68536776304245},
#   {'corpus_id': 35, 'score': 0.6747523546218872}],
#  [{'corpus_id': 266, 'score': 0.7094408273696899},
#   {'corpus_id': 292, 'score': 0.6239012479782104},
#   {'corpus_id': 87, 'score': 0.6216291785240173}],
#  [{'corpus_id': 111, 'score': 0.6403840184211731},
#   {'corpus_id': 282, 'score': 0.6379724144935608},
#   {'corpus_id': 292, 'score': 0.636170506477356}],
#  [{'corpus_id': 111, 'score': 0.673671305179596},
#   {'corpus_id': 124, 'score': 0.6521689295768738},
#   {'corpus_id': 87, 'score': 0.6471929550170898}],
#  [{'corpus_id': 268, 'score': 0.9616448879241943},
#   {'corpus_id': 276, 'score': 0.7815624475479126},
#   {'corpus_id': 243, 'score': 0.7780316472053528}],
#  [{'corpus_id': 268, 'score': 0.9242367148399353},
#   {'corpus_id': 280, 'score': 0.81295245885849},
#   {'corpus_id': 243, 'score': 0.7987524271011353}],
#  [{'corpus_id': 269, 'score': 0.8030692338943481},
#   {'corpus_id': 80, 'score': 0.599873423576355},
#   {'corpus_id': 70, 'score': 0.5963781476020813}],
#  [{'corpus_id': 102, 'score': 0.7460839748382568},
#   {'corpus_id': 20, 'score': 0.730229914188385},
#   {'corpus_id': 297, 'score': 0.7172453999519348}],
#  [{'corpus_id': 271, 'score': 0.9999996423721313},
#   {'corpus_id': 59, 'score': 0.8247095942497253},
#   {'corpus_id': 106, 'score': 0.8094907402992249}],
#  [{'corpus_id': 273, 'score': 0.9510065317153931},
#   {'corpus_id': 223, 'score': 0.8757683038711548},
#   {'corpus_id': 244, 'score': 0.8153352737426758}],
#  [{'corpus_id': 292, 'score': 0.7180911302566528},
#   {'corpus_id': 298, 'score': 0.6925139427185059},
#   {'corpus_id': 282, 'score': 0.6316315531730652}],
#  [{'corpus_id': 108, 'score': 0.5565366148948669},
#   {'corpus_id': 14, 'score': 0.5489474534988403},
#   {'corpus_id': 278, 'score': 0.5293964147567749}],
#  [{'corpus_id': 280, 'score': 1.0},
#   {'corpus_id': 45, 'score': 0.867469847202301},
#   {'corpus_id': 126, 'score': 0.8649558424949646}],
#  [{'corpus_id': 281, 'score': 0.9872022867202759},
#   {'corpus_id': 291, 'score': 0.8501494526863098},
#   {'corpus_id': 228, 'score': 0.8135222792625427}],
#  [{'corpus_id': 282, 'score': 0.9893621206283569},
#   {'corpus_id': 92, 'score': 0.7386560440063477},
#   {'corpus_id': 10, 'score': 0.7004797458648682}],
#  [{'corpus_id': 282, 'score': 0.8946458101272583},
#   {'corpus_id': 281, 'score': 0.7266591191291809},
#   {'corpus_id': 34, 'score': 0.6705004572868347}],
#  [{'corpus_id': 283, 'score': 0.9887209534645081},
#   {'corpus_id': 290, 'score': 0.7102212309837341},
#   {'corpus_id': 285, 'score': 0.6106392741203308}],
#  [{'corpus_id': 283, 'score': 0.9557266235351562},
#   {'corpus_id': 290, 'score': 0.6339859366416931},
#   {'corpus_id': 285, 'score': 0.5915012359619141}],
#  [{'corpus_id': 284, 'score': 0.9867181777954102},
#   {'corpus_id': 112, 'score': 0.9384962320327759},
#   {'corpus_id': 138, 'score': 0.8121577501296997}],
#  [{'corpus_id': 285, 'score': 0.9999993443489075},
#   {'corpus_id': 68, 'score': 0.855164647102356},
#   {'corpus_id': 260, 'score': 0.8330731391906738}],
#  [{'corpus_id': 285, 'score': 0.9353330731391907},
#   {'corpus_id': 35, 'score': 0.8374094367027283},
#   {'corpus_id': 95, 'score': 0.8180893063545227}],
#  [{'corpus_id': 286, 'score': 0.729887068271637},
#   {'corpus_id': 149, 'score': 0.45641428232192993},
#   {'corpus_id': 253, 'score': 0.44120103120803833}],
#  [{'corpus_id': 287, 'score': 0.8390676975250244},
#   {'corpus_id': 229, 'score': 0.7299198508262634},
#   {'corpus_id': 170, 'score': 0.7124980688095093}],
#  [{'corpus_id': 287, 'score': 0.9025366902351379},
#   {'corpus_id': 34, 'score': 0.7393080592155457},
#   {'corpus_id': 93, 'score': 0.7372658848762512}],
#  [{'corpus_id': 288, 'score': 0.9679613709449768},
#   {'corpus_id': 223, 'score': 0.7543722987174988},
#   {'corpus_id': 150, 'score': 0.742169976234436}],
#  [{'corpus_id': 6, 'score': 0.7509129047393799},
#   {'corpus_id': 289, 'score': 0.7130129933357239},
#   {'corpus_id': 119, 'score': 0.6553953289985657}],
#  [{'corpus_id': 289, 'score': 0.9330636262893677},
#   {'corpus_id': 34, 'score': 0.6731564402580261},
#   {'corpus_id': 135, 'score': 0.6617568135261536}],
#  [{'corpus_id': 290, 'score': 0.9488652348518372},
#   {'corpus_id': 95, 'score': 0.8452752828598022},
#   {'corpus_id': 94, 'score': 0.7662308216094971}],
#  [{'corpus_id': 180, 'score': 0.7561165690422058},
#   {'corpus_id': 178, 'score': 0.7555495500564575},
#   {'corpus_id': 176, 'score': 0.7420142889022827}],
#  [{'corpus_id': 292, 'score': 0.9887831807136536},
#   {'corpus_id': 298, 'score': 0.7648142576217651},
#   {'corpus_id': 282, 'score': 0.6380743980407715}],
#  [{'corpus_id': 292, 'score': 0.8968024253845215},
#   {'corpus_id': 275, 'score': 0.6510039567947388},
#   {'corpus_id': 279, 'score': 0.6471627354621887}],
#  [{'corpus_id': 35, 'score': 0.8565268516540527},
#   {'corpus_id': 293, 'score': 0.8389695882797241},
#   {'corpus_id': 95, 'score': 0.8120887279510498}],
#  [{'corpus_id': 293, 'score': 0.993715763092041},
#   {'corpus_id': 177, 'score': 0.9159818291664124},
#   {'corpus_id': 48, 'score': 0.8279813528060913}],
#  [{'corpus_id': 169, 'score': 0.8489927053451538},
#   {'corpus_id': 170, 'score': 0.8319966197013855},
#   {'corpus_id': 171, 'score': 0.8237261772155762}],
#  [{'corpus_id': 295, 'score': 0.7365036606788635},
#   {'corpus_id': 180, 'score': 0.6408264636993408},
#   {'corpus_id': 178, 'score': 0.6352254748344421}],
#  [{'corpus_id': 296, 'score': 0.8584360480308533},
#   {'corpus_id': 94, 'score': 0.7858826518058777},
#   {'corpus_id': 285, 'score': 0.7681179046630859}],
#  [{'corpus_id': 296, 'score': 0.8928667902946472},
#   {'corpus_id': 205, 'score': 0.8539344072341919},
#   {'corpus_id': 198, 'score': 0.8430986404418945}],
#  [{'corpus_id': 244, 'score': 0.7743439078330994},
#   {'corpus_id': 240, 'score': 0.747941792011261},
#   {'corpus_id': 298, 'score': 0.7344033718109131}],
#  [{'corpus_id': 298, 'score': 0.8479441404342651},
#   {'corpus_id': 292, 'score': 0.6114348769187927},
#   {'corpus_id': 275, 'score': 0.5637338161468506}]]

# %% [markdown]
# ## 5. Оценка модели

# %%
def best_result(df):
    i = sorted(df, key=lambda d: d['score'])
    return i[-1]['corpus_id']

# %%
df_test['candidate_idx'] = [best_result(x) for x in result]
df_test['candidate_school_id'] = df_train.school_id.values[df_test.candidate_idx.values]
df_test['candidate_name'] = df_test.name_variant.values[df_test.candidate_idx.values]
display(df_test)

accuracy = round((df_test.school_id == df_test.candidate_school_id).sum()/df_test.shape[0], 2)
print(f"Accuracy: {accuracy:.2f}%")
# Out:
#      school_id                                       name_variant  \
# 887          1       московская область спортивная школа авангард
# 886          2                     янао спортивная школа авангард
# 884          3  спортивная школа олимпийского резерва фсо авиа...
# 883          3  республика татарстан спортивная школа олимпийс...
# 882          3  республика татарстан муниципальное бюджетное у...
# ..         ...                                                ...
# 4          609                          спортивная школа гвоздика
# 3          610  саратовская область государственное бюджетное ...
# 2          610  спортивная школа олимпийского резерва надежда ...
# 1         1836                      москва спортивный клуб триумф
# 0         1836      общество ограниченной ответственностью триумф
#
#      candidate_idx  candidate_school_id  \
# 887              0                    1
# 886            168                  173
# 884            195                  201
# 883            195                  201
# 882            138                  143
# ..             ...                  ...
# 4              295                  609
# 3              296                  610
# 2              296                  610
# 1              244                  251
# 0              298                 1836
#
#                                         candidate_name
# 887       московская область спортивная школа авангард
# 886  курганская область детско юношеская спортивная...
# 884  спб государственное бюджетное учреждение спорт...
# 883  спб государственное бюджетное учреждение спорт...
# 882  санкт петербург спб гбпоу алвс динамо санкт пе...
# ..                                                 ...
# 4    московская область муниципальное автономное уч...
# 3    московская область муниципальное автономное уч...
# 2    московская область муниципальное автономное уч...
# 1    москва государственное бюджетное учреждение мо...
# 0    муниципальное автономное учреждение спортивная...
#
# [888 rows x 5 columns]
# Accuracy: 0.41%

# %% [markdown]
# ## 6. Итоговый вывод

# %% [markdown]
# 1. Данные представляют собой две таблицы, в одной эталонные наименования спортивных школ, в другой вариации написания в том числе с ошибками.
# 2. В эталонной таблице всего 306 строк и 3 колонки - id школы, регион, наименование
# 3. Во второй таблице всего 895 строк и 2 колонки - id школы,  наименование (в части случаев указано с регионом)
# 4. Эталонную таблицу, используем как тренировачную выборку, другую как тестовую.
# 5. Пропуски  в дататсетах не обнаружены.
# 6. При обработке данных выявили дубликаты и удалили их.
# 7. В тренировочный датасет добавлен признак - наименование с расшифрованной аббревиатурой
# 8. Все наименования приведены к нижнему регистру, удалены ненужные символы, пробелы и знаки
# 9. На тренировочной выборке проведена аугментация путем побавления 7 дубликатов с ошибками и перемены слов местами для того чтобы в дальнейшем дообучить модель на этих данных.
# 10. Протестирована модель sentence-transformers - LaBSE
# 11. Получен результат (доля правильно определенных наименований) Accuracy:
# 12. Результат нуждается в улучшении, можно попробовать дообучить модель на тренировочных данных, увеличить количество признаков (добавить колонки с разными вариантами написаний названий школ) , потестировать другие модели.
# 13. Рекомендация заказчику: в эталонном датасете присутствуют опечатки, написание одних и тех же названий в разном регистре, чего не должно быть - при обработке данных выявили дубликаты и удалили их. Но наверняка этим дубликатам не просто так присвоили уникальные id - наверняка по ним сформированы заявки и т д, рекомендуется ручная проверка эталонных данных.
